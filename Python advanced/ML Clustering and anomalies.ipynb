# %% [markdown]
# Используя исходные или очищенные данные, сформируйте предсказание класса объявления из множества exposition_test.tsv.gz
#
# Обязательно нужно использовать одну или несколько моделей кластеризации. Дополнительно можно использовать решающие деревья, CatBoost, LightGBM и XGBoost.
#
# Подсказка: для использования day_mean в классификации/кластеризации потребуется его сформировать для тестовых данных. Это можно сделать либо при помощи других моделей (два этапа классификации), либо построив линейную модель прогноза day_mean от count_day.
#
# Данные:
# * https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_train.tsv.gz
# * https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_test.tsv.gz
# * https://video.ittensive.com/machine-learning/hacktherealty/data/metro.utf8.json
# * https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_sample_submisson.tsv
#
# Итоговый файл с кодом (.py или .ipynb) выложите в github с портфолио.

# %% [markdown]
# # ------------------------------

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from transliterate import translit
from tqdm import notebook
from pyod.models.iforest import IForest
from pyod.models.copod import COPOD
from sklearn.neighbors import LocalOutlierFactor

from catboost import Pool, CatBoostClassifier
from xgboost import XGBClassifier

# %%
def data_preproccesing (data):
# add total items per day
    data_day_count = data.groupby("day").count()["build_year"]
    data["day_count"] = data["day"].apply(lambda x:data_day_count.loc[x])
# approximate values (clean-up)
    data.loc[data.build_year == 0, 'build_year'] = np.NaN
    data['build_year'] = data['build_year'].fillna((data.groupby(['building_series_id'])['build_year'].transform('median')))
    data.loc[data['build_year'].isna(), 'build_year'] = data['build_year'].mean()
    data['build_year'] = data['build_year'].astype(np.uint16)
    if 'has_elevator' in data.columns:
# elevator for 6+ floors
        data.loc[(data.has_elevator==0) & (data.floor>5), 'has_elevator'] = 1
# fix living area
    data.loc[data.living_area == 0, 'living_area'] = np.NaN
    data['living_area'] = data['living_area'].fillna((data.groupby(['rooms'])['living_area'].transform('median')))
# fix price
    data.loc[data.price<100, 'price'] *= 1000
    data.loc[data.price<1000, 'price'] *= 60
    if 'floors_total' in data.columns:
# fix celing height
        data.loc[(data.ceiling_height<2) | (data.ceiling_height>5), 'ceiling_height'] = np.NaN
        data['ceiling_height'] = data['ceiling_height'].fillna(data.groupby(['building_series_id'])['ceiling_height'].transform('median'))
        data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data['ceiling_height'].mean()
# enrich data, % floor
        data['floor'] = data['floor'] / data["floors_total"]
# locality, village/region/moscow/metro
    if 'locality_name' in data.columns:
        data['loctype_village'] = (data['locality_name'].str.match(pat = 'городок|деревня|ДНП|поселок|посёлок|село|СНТ|товарищество|хутор')).astype(np.uint8)
        data['loctype_moscow'] = (data.locality_name == 'Москва').astype(np.uint8)
        data['loctype_region'] = ((data.loctype_village == 0) & (data.loctype_moscow == 0)).astype(np.uint8)
    if "site_id" in data.columns:
        data = data.drop(['site_id', 'main_image', 'area', 'building_id', 'unified_address'], axis=1)
    if 'target_string' in data.columns:
        data = data.drop(['target_string'], axis=1)
# processing date
    if 'day' in data.columns:
        data['day'] = pd.to_datetime(data['day'])
        data['year'] = data['day'].dt.year
        data['month'] = data['day'].dt.month
        data['week'] = data['day'].dt.week
        data['dow'] = data['day'].dt.dayofweek
        data['dom'] = data['day'].dt.day
        data['doy'] = data['day'].dt.dayofyear
        data = data.drop(["day"], axis=1)
# adding holydays, 1-7 Jan, 8 Mar, 1 May, 9 May, 12 Jun, 4 Nov
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2017/
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2018/
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2019/
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2020/
        data['is_holyday'] = ((data['year'] == 2017 &
                                (((data['dom'] > 0) & (data['dom'] < 8) & data['month'] == 1) | 
                                (((data['dom'] == 23) | data['dom'] == 24)) & (data['month'] == 2)) |
                                ((data['dom'] == 8) & (data['month'] == 3)) |
                                (((data['dom'] == 1) | (data['dom'] == 8) | (data['dom'] == 9)) & data['month'] == 5) |
                                ((data['dom'] == 12) & (data['month'] == 6)) |
                                ((data['dom'] == 6) & (data['month'] == 11))) |
                              ((data['year'] == 2018) &
                                (((data['dom'] > 0) & (data['dom'] < 9) & data['month'] == 1) | 
                                ((data['dom'] == 23) & (data['month'] == 2)) |
                                (((data['dom'] == 8) | (data['dom'] == 9)) & (data['month'] == 3)) |
                                ((data['dom'] == 30) & (data['month'] == 4)) |
                                (((data['dom'] == 1) | (data['dom'] == 2) | (data['dom'] == 9)) & data['month'] == 5) |
                                (((data['dom'] == 11) | (data['dom'] == 12)) & (data['month'] == 6)) |
                                ((data['dom'] == 5) & (data['month'] == 11)) |
                                ((data['dom'] == 31) & (data['month'] == 12)))) |
                              ((data['year'] == 2019) &
                                (((data['dom'] > 0) & (data['dom'] < 9) & data['month'] == 1) | 
                                ((data['dom'] == 8) & (data['month'] == 3)) |
                                (((data['dom'] == 1) | (data['dom'] == 2) | (data['dom'] == 3) | (data['dom'] == 9) | (data['dom'] == 10)) & data['month'] == 5) |
                                ((data['dom'] == 12) & (data['month'] == 6)) |
                                ((data['dom'] == 4) & (data['month'] == 11)))) |
                              ((data['year'] == 2020) &
                                (((data['dom'] > 0) & (data['dom'] < 9) & data['month'] == 1) | 
                                ((data['dom'] == 24) & (data['month'] == 2)) |
                                ((data['dom'] == 9) & (data['month'] == 3)) |
                                (((data['dom'] == 1) | (data['dom'] == 4) | (data['dom'] == 5) | (data['dom'] == 11)) & data['month'] == 5) |
                                ((data['dom'] == 12) & (data['month'] == 6)) |
                                ((data['dom'] == 4) & (data['month'] == 11))))).astype(np.uint8)
# one-hot vectors
    if 'year' in data.columns:
        for label in ['year', 'month', 'week', 'dow', 'doy', 'dom', 'renovation',
                      'balcony', 'building_type', 'parking', 'floors_total', 'locality_name']:
            for l in data[label].unique():
                data[label + "_" + translit(str(l), "ru", reversed=True)] = (data[label] == l).astype(np.uint8)
# boolean -> int
    if 'studio' in data.columns:
        for label in ['studio', 'has_elevator', 'expect_demolition', 'is_apartment']:
            data[label] = data[label].astype(np.uint8)
# index (remove id from columns)
    if 'id' in data.columns:
        data = data.set_index(['id'])
    return data

# %%
def calc_price (data, group="", label=""):
    if data[group] in price_groups[group][label]:
        return data["price"] / price_groups[group][label][data[group]]
    else:
        return 1

# %%
train_data = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/exposition_train.basic.csv.gz')
train_data = train_data.drop(labels=["doy_108"], axis=1)
train_data.head()
# Out:
#    total_area  ceiling_height  rooms  living_area  price  day_mean  \
# 0  105.000000            3.00      3    50.000000  95000  2.456912
# 1   40.000000            3.00      1    19.200001  25000  3.028689
# 2   37.599998            2.64      0    19.000000  26000  3.091993
# 3   80.000000            3.00      3    49.000000  35000  3.101010
# 4  100.000000            3.00      3    49.000000  80000  2.495468
#
#    price_locality_name_median  target
# 0                    2.261905       1
# 1                    1.000000       2
# 2                    0.619048       2
# 3                    1.250000       2
# 4                    1.904762       3

# %% [markdown]
# ### Нормализация данных
# Приведение всех значений к отрезку [0;1], удалим из данных target

# %%
target = train_data["target"]

# %%
scaler = StandardScaler()

# %%
train_data_mm = pd.DataFrame(scaler.fit_transform(train_data[train_data.columns[:-1]]))

# %%
train_data_mm.head()
# Out:
#           0         1         2         3         4         5         6
# 0  1.709793  1.115052  1.469889  1.025395  0.378181 -1.607090  0.278301
# 1 -0.483202  1.115052 -0.861151 -0.679471 -0.217544  0.337784 -0.132179
# 2 -0.564174 -0.645106 -2.026671 -0.690542 -0.209033  0.553112 -0.256098
# 3  0.866333  1.115052  1.469889  0.970042 -0.132440  0.583783 -0.050858
# 4  1.541101  1.115052  1.469889  0.970042  0.250526 -1.475943  0.162128

# %% [markdown]
# # K-means

# %%
kmeans = KMeans(n_clusters=100, random_state=0, max_iter=200, n_init=10).fit(train_data_mm)

# %%
train_data_mm["label"] = kmeans.labels_
train_data_mm["target"] = train_data["target"]

# %% [markdown]
# # Модели классификации

# %% [markdown]
# ### XGBoost = градиентный бустинг деревьев решений
# (Получим кластеры по всем данным)
# Получим модель XGB

# %%
y = train_data_mm["label"]
x = train_data_mm.drop(labels=["label", "target"], axis=1)

# %%
xgb_model = XGBClassifier(max_depth=17, max_features=27,
                          n_estimators=76, min_samples_leaf=20)

# %%
xgb_model.fit(x, y)
# Out:
# E:\anaconda\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:18:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "max_features", "min_samples_leaf" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:18:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=17, max_features=27,
#               min_child_weight=1, min_samples_leaf=20, missing=nan,
#               monotone_constraints='()', n_estimators=76, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1, ...)

# %% [markdown]
# # CatBoost

# %%
train_dataset = Pool(data=x, label=y)
catboost_model = CatBoostClassifier(iterations=10, learning_rate=0.57,
                 random_seed=17, depth=6, loss_function="MultiClass",
                 bootstrap_type="MVS", custom_metric="WKappa")

# %%
cb_params = {
    "depth": range(5,8),
    'learning_rate': np.arange(0.56,0.59,0.01),
    'l2_leaf_reg': range(1,5),
}

cb_grid = catboost_model.grid_search(cb_params, cv=5, X=x, y=y, verbose=True)

print (cb_grid["params"])

catboost_model= CatBoostClassifier(iterations=100,
                learning_rate=cb_grid["params"]["learning_rate"],
                depth=cb_grid["params"]["depth"],
                l2_leaf_reg=cb_grid["params"]["l2_leaf_reg"],
                random_seed=17, loss_function="MultiClass",
                bootstrap_type="MVS", custom_metric="WKappa")
# Out:
# 0:	learn: 7.2138556	test: 7.2589252	best: 7.2589252 (0)	total: 3.2s	remaining: 28.8s
# 1:	learn: 2157.0821597	test: 2143.4098638	best: 7.2589252 (0)	total: 6.55s	remaining: 26.2s
# 2:	learn: 2285.1337115	test: 2285.9242313	best: 7.2589252 (0)	total: 8.44s	remaining: 19.7s
# 3:	learn: 4252.2601570	test: 4250.1755723	best: 7.2589252 (0)	total: 10.3s	remaining: 15.4s
# 4:	learn: 4682.8077174	test: 4675.9563168	best: 7.2589252 (0)	total: 12.1s	remaining: 12.1s
# 5:	learn: 4313.2519432	test: 4330.4528156	best: 7.2589252 (0)	total: 13.8s	remaining: 9.23s
# 6:	learn: 4468.4438622	test: 4488.9407072	best: 7.2589252 (0)	total: 15.6s	remaining: 6.7s
# 7:	learn: 4231.6619318	test: 4242.8036978	best: 7.2589252 (0)	total: 17.4s	remaining: 4.36s
# 8:	learn: 3892.2358070	test: 3904.9930441	best: 7.2589252 (0)	total: 19.6s	remaining: 2.18s
# 9:	learn: 3929.0414109	test: 3932.3922368	best: 7.2589252 (0)	total: 21.7s	remaining: 0us
#
# bestTest = 7.258925184
# bestIteration = 0
#
# 0:	loss: 7.2589252	best: 7.2589252 (0)	total: 22.7s	remaining: 13m 14s
# 0:	learn: 7.3396199	test: 7.3855003	best: 7.3855003 (0)	total: 2.17s	remaining: 19.6s
# 1:	learn: 2214.5143027	test: 2200.3250156	best: 7.3855003 (0)	total: 4.52s	remaining: 18.1s
# 2:	learn: 2320.0685485	test: 2320.3667521	best: 7.3855003 (0)	total: 6.62s	remaining: 15.5s
# 3:	learn: 4145.0719924	test: 4143.1135884	best: 7.3855003 (0)	total: 8.6s	remaining: 12.9s
# 4:	learn: 4875.6064611	test: 4868.4354026	best: 7.3855003 (0)	total: 10.5s	remaining: 10.5s
# 5:	learn: 4381.2911020	test: 4398.4217104	best: 7.3855003 (0)	total: 12.9s	remaining: 8.61s
# 6:	learn: 4459.5222125	test: 4479.9309621	best: 7.3855003 (0)	total: 15.1s	remaining: 6.45s
# 7:	learn: 4324.2675993	test: 4335.3326964	best: 7.3855003 (0)	total: 17.2s	remaining: 4.31s
# 8:	learn: 4087.4441887	test: 4118.8723846	best: 7.3855003 (0)	total: 19.2s	remaining: 2.13s
# 9:	learn: 3882.1051051	test: 3890.2271761	best: 7.3855003 (0)	total: 21.1s	remaining: 0us
#
# bestTest = 7.385500303
# bestIteration = 0
#
# 1:	loss: 7.3855003	best: 7.2589252 (0)	total: 44.3s	remaining: 12m 33s
# 0:	learn: 7.4655210	test: 7.5122126	best: 7.5122126 (0)	total: 1.99s	remaining: 17.9s
# 1:	learn: 2272.7344369	test: 2257.9730596	best: 7.5122126 (0)	total: 3.9s	remaining: 15.6s
# 2:	learn: 2354.6375115	test: 2354.3527412	best: 7.5122126 (0)	total: 5.95s	remaining: 13.9s
# 3:	learn: 4347.0443793	test: 4344.1231231	best: 7.5122126 (0)	total: 7.91s	remaining: 11.9s
# 4:	learn: 4989.4697852	test: 4981.6177925	best: 7.5122126 (0)	total: 10.1s	remaining: 10.1s
# 5:	learn: 4485.7144219	test: 4502.5418565	best: 7.5122126 (0)	total: 12s	remaining: 8s
# 6:	learn: 4576.4637416	test: 4598.3754978	best: 7.5122126 (0)	total: 13.9s	remaining: 5.97s
# 7:	learn: 4492.5685313	test: 4503.9826109	best: 7.5122126 (0)	total: 15.8s	remaining: 3.96s
# 8:	learn: 3787.2539311	test: 3798.7588753	best: 7.5122126 (0)	total: 17.8s	remaining: 1.97s
# 9:	learn: 5078.1063340	test: 5079.6727696	best: 7.5122126 (0)	total: 19.7s	remaining: 0us
#
# bestTest = 7.512212617
# bestIteration = 0
#
# 2:	loss: 7.5122126	best: 7.2589252 (0)	total: 1m 4s	remaining: 11m 48s
# 0:	learn: 7.1702109	test: 7.2145594	best: 7.2145594 (0)	total: 1.93s	remaining: 17.3s
# 1:	learn: 1107.9331202	test: 1100.4341563	best: 7.2145594 (0)	total: 3.86s	remaining: 15.4s
# 2:	learn: 1156.8373622	test: 1156.4708791	best: 7.2145594 (0)	total: 6.24s	remaining: 14.6s
# 3:	learn: 2094.1646032	test: 2101.1043702	best: 7.2145594 (0)	total: 8.23s	remaining: 12.3s
# 4:	learn: 2487.1548590	test: 2485.0592129	best: 7.2145594 (0)	total: 10.2s	remaining: 10.2s
# 5:	learn: 2190.9080810	test: 2203.1116913	best: 7.2145594 (0)	total: 12.1s	remaining: 8.08s
# 6:	learn: 2114.9535438	test: 2131.2024167	best: 7.2145594 (0)	total: 14.3s	remaining: 6.11s
# 7:	learn: 2526.9715649	test: 2547.0164247	best: 7.2145594 (0)	total: 16.3s	remaining: 4.07s
# 8:	learn: 2615.8823431	test: 2635.6552304	best: 7.2145594 (0)	total: 18.3s	remaining: 2.04s
# 9:	learn: 2038.0189457	test: 2046.1690171	best: 7.2145594 (0)	total: 20.4s	remaining: 0us
#
# bestTest = 7.214559413
# bestIteration = 0
#
# 3:	loss: 7.2145594	best: 7.2145594 (3)	total: 1m 25s	remaining: 11m 22s
# 0:	learn: 7.2951616	test: 7.3403079	best: 7.3403079 (0)	total: 2.03s	remaining: 18.3s
# 1:	learn: 1137.8108922	test: 1129.9570987	best: 7.3403079 (0)	total: 3.95s	remaining: 15.8s
# 2:	learn: 1198.6171717	test: 1198.0466213	best: 7.3403079 (0)	total: 5.92s	remaining: 13.8s
# 3:	learn: 2196.4600634	test: 2200.6370013	best: 7.3403079 (0)	total: 7.91s	remaining: 11.9s
# 4:	learn: 2454.3300003	test: 2456.7667413	best: 7.3403079 (0)	total: 9.95s	remaining: 9.95s
# 5:	learn: 2223.3405357	test: 2236.6574150	best: 7.3403079 (0)	total: 11.9s	remaining: 7.92s
# 6:	learn: 2191.0893582	test: 2208.7793192	best: 7.3403079 (0)	total: 13.8s	remaining: 5.93s
# 7:	learn: 2505.7094537	test: 2527.6082214	best: 7.3403079 (0)	total: 15.9s	remaining: 3.97s
# 8:	learn: 2709.7241489	test: 2729.7511349	best: 7.3403079 (0)	total: 18.1s	remaining: 2.01s
# 9:	learn: 2085.1915513	test: 2093.8481312	best: 7.3403079 (0)	total: 20s	remaining: 0us
#
# bestTest = 7.340307911
# bestIteration = 0
#
# 4:	loss: 7.3403079	best: 7.2145594 (3)	total: 1m 45s	remaining: 10m 55s
# 0:	learn: 7.4202510	test: 7.4661955	best: 7.4661955 (0)	total: 1.92s	remaining: 17.3s
# 1:	learn: 1167.9787190	test: 1159.7433982	best: 7.4661955 (0)	total: 3.81s	remaining: 15.3s
# 2:	learn: 1266.9871218	test: 1266.2707727	best: 7.4661955 (0)	total: 5.8s	remaining: 13.5s
# 3:	learn: 2294.5998236	test: 2301.5319781	best: 7.4661955 (0)	total: 7.69s	remaining: 11.5s
# 4:	learn: 2375.8646109	test: 2371.1634282	best: 7.4661955 (0)	total: 9.77s	remaining: 9.77s
# 5:	learn: 2266.9810315	test: 2283.8997668	best: 7.4661955 (0)	total: 11.9s	remaining: 7.96s
# 6:	learn: 2128.4148790	test: 2146.3057851	best: 7.4661955 (0)	total: 13.9s	remaining: 5.96s
# 7:	learn: 2672.5882682	test: 2682.7318590	best: 7.4661955 (0)	total: 15.8s	remaining: 3.95s
# 8:	learn: 2490.1038863	test: 2492.1260666	best: 7.4661955 (0)	total: 17.7s	remaining: 1.96s
# 9:	learn: 2492.3408584	test: 2483.7662753	best: 7.4661955 (0)	total: 19.6s	remaining: 0us
#
# bestTest = 7.466195546
# bestIteration = 0
#
# 5:	loss: 7.4661955	best: 7.2145594 (3)	total: 2m 5s	remaining: 10m 28s
# 0:	learn: 7.1275921	test: 7.1712555	best: 7.1712555 (0)	total: 1.89s	remaining: 17s
# 1:	learn: 749.0632816	test: 743.7244560	best: 7.1712555 (0)	total: 3.83s	remaining: 15.3s
# 2:	learn: 822.2582948	test: 821.9030548	best: 7.1712555 (0)	total: 6.14s	remaining: 14.3s
# 3:	learn: 1469.0078594	test: 1473.6344838	best: 7.1712555 (0)	total: 8.16s	remaining: 12.2s
# 4:	learn: 1499.8099718	test: 1497.0006272	best: 7.1712555 (0)	total: 10.4s	remaining: 10.4s
# 5:	learn: 1431.5767096	test: 1442.3126478	best: 7.1712555 (0)	total: 12.3s	remaining: 8.21s
# 6:	learn: 1230.2032807	test: 1243.5772978	best: 7.1712555 (0)	total: 14.2s	remaining: 6.1s
# 7:	learn: 1574.5299441	test: 1584.0209492	best: 7.1712555 (0)	total: 16.2s	remaining: 4.06s
# 8:	learn: 1403.9919635	test: 1411.0234360	best: 7.1712555 (0)	total: 18.2s	remaining: 2.02s
# 9:	learn: 1430.9831794	test: 1432.0713186	best: 7.1712555 (0)	total: 20.5s	remaining: 0us
#
# bestTest = 7.171255538
# bestIteration = 0
#
# 6:	loss: 7.1712555	best: 7.1712555 (6)	total: 2m 26s	remaining: 10m 7s
# 0:	learn: 7.2517471	test: 7.2961960	best: 7.2961960 (0)	total: 1.93s	remaining: 17.4s
# 1:	learn: 769.1514305	test: 763.5451858	best: 7.2961960 (0)	total: 4.1s	remaining: 16.4s
# 2:	learn: 870.4208372	test: 869.9704929	best: 7.2961960 (0)	total: 6.07s	remaining: 14.2s
# 3:	learn: 1468.4991839	test: 1472.8937754	best: 7.2961960 (0)	total: 7.91s	remaining: 11.9s
# 4:	learn: 1531.1434329	test: 1528.0732144	best: 7.2961960 (0)	total: 10s	remaining: 10s
# 5:	learn: 1358.3318982	test: 1369.2848145	best: 7.2961960 (0)	total: 12s	remaining: 7.99s
# 6:	learn: 1248.1705150	test: 1261.8275720	best: 7.2961960 (0)	total: 14s	remaining: 5.99s
# 7:	learn: 1465.3806814	test: 1476.9079124	best: 7.2961960 (0)	total: 16.2s	remaining: 4.04s
# 8:	learn: 1647.4650648	test: 1656.2405329	best: 7.2961960 (0)	total: 18.2s	remaining: 2.02s
# 9:	learn: 1370.9011102	test: 1372.0866377	best: 7.2961960 (0)	total: 20.4s	remaining: 0us
#
# bestTest = 7.29619601
# bestIteration = 0
#
# 7:	loss: 7.2961960	best: 7.1712555 (6)	total: 2m 47s	remaining: 9m 46s
# 0:	learn: 7.3760428	test: 7.4212776	best: 7.4212776 (0)	total: 1.92s	remaining: 17.3s
# 1:	learn: 789.3403990	test: 783.4524022	best: 7.4212776 (0)	total: 3.82s	remaining: 15.3s
# 2:	learn: 919.4661439	test: 918.9028071	best: 7.4212776 (0)	total: 5.79s	remaining: 13.5s
# 3:	learn: 1467.5505311	test: 1471.6842709	best: 7.4212776 (0)	total: 7.66s	remaining: 11.5s
# 4:	learn: 1568.2908724	test: 1565.0023350	best: 7.4212776 (0)	total: 9.8s	remaining: 9.8s
# 5:	learn: 1505.3546273	test: 1516.4314161	best: 7.4212776 (0)	total: 11.7s	remaining: 7.79s
# 6:	learn: 1421.1962896	test: 1435.0481722	best: 7.4212776 (0)	total: 13.8s	remaining: 5.9s
# 7:	learn: 1722.9414533	test: 1731.5533588	best: 7.4212776 (0)	total: 15.9s	remaining: 3.98s
# 8:	learn: 1674.1567231	test: 1675.6706833	best: 7.4212776 (0)	total: 17.9s	remaining: 1.98s
# 9:	learn: 1646.4693428	test: 1649.6888967	best: 7.4212776 (0)	total: 19.9s	remaining: 0us
#
# bestTest = 7.421277581
# bestIteration = 0
#
# 8:	loss: 7.4212776	best: 7.1712555 (6)	total: 3m 7s	remaining: 9m 23s
# 0:	learn: 7.0859386	test: 7.1289498	best: 7.1289498 (0)	total: 1.87s	remaining: 16.8s
# 1:	learn: 566.4504820	test: 562.2508229	best: 7.1289498 (0)	total: 3.71s	remaining: 14.9s
# 2:	learn: 652.5317842	test: 652.3522045	best: 7.1289498 (0)	total: 6.4s	remaining: 14.9s
# 3:	learn: 1073.7370736	test: 1077.0827958	best: 7.1289498 (0)	total: 8.5s	remaining: 12.8s
# 4:	learn: 1126.8303814	test: 1124.7353466	best: 7.1289498 (0)	total: 10.6s	remaining: 10.6s
# 5:	learn: 1008.2057068	test: 1016.0170021	best: 7.1289498 (0)	total: 12.6s	remaining: 8.4s
# 6:	learn: 930.4188839	test: 940.7110400	best: 7.1289498 (0)	total: 14.6s	remaining: 6.24s
# 7:	learn: 1190.7584267	test: 1198.3938559	best: 7.1289498 (0)	total: 16.5s	remaining: 4.13s
# 8:	learn: 1145.5534283	test: 1149.1533207	best: 7.1289498 (0)	total: 18.4s	remaining: 2.04s
# 9:	learn: 1032.7694105	test: 1036.0440378	best: 7.1289498 (0)	total: 20.4s	remaining: 0us
#
# bestTest = 7.128949828
# bestIteration = 0
#
# 9:	loss: 7.1289498	best: 7.1289498 (9)	total: 3m 28s	remaining: 9m 2s
# 0:	learn: 7.2093148	test: 7.2530997	best: 7.2530997 (0)	total: 1.9s	remaining: 17.1s
# 1:	learn: 581.5003932	test: 577.0881479	best: 7.2530997 (0)	total: 3.79s	remaining: 15.1s
# 2:	learn: 689.8975369	test: 689.6452075	best: 7.2530997 (0)	total: 6.74s	remaining: 15.7s
# 3:	learn: 1073.3504305	test: 1076.5027634	best: 7.2530997 (0)	total: 8.7s	remaining: 13s
# 4:	learn: 1149.5951249	test: 1147.3234327	best: 7.2530997 (0)	total: 10.6s	remaining: 10.6s
# 5:	learn: 1021.4642044	test: 1029.2777203	best: 7.2530997 (0)	total: 12.6s	remaining: 8.39s
# 6:	learn: 955.7627866	test: 966.0778972	best: 7.2530997 (0)	total: 14.5s	remaining: 6.23s
# 7:	learn: 1244.2151119	test: 1253.1421305	best: 7.2530997 (0)	total: 16.4s	remaining: 4.1s
# 8:	learn: 1191.7522311	test: 1195.8704882	best: 7.2530997 (0)	total: 18.4s	remaining: 2.04s
# 9:	learn: 1120.6721314	test: 1124.5466572	best: 7.2530997 (0)	total: 20.5s	remaining: 0us
#
# bestTest = 7.253099725
# bestIteration = 0
#
# 10:	loss: 7.2530997	best: 7.1289498 (9)	total: 3m 49s	remaining: 8m 41s
# 0:	learn: 7.3328336	test: 7.3773927	best: 7.3773927 (0)	total: 1.93s	remaining: 17.4s
# 1:	learn: 596.5691922	test: 591.9362848	best: 7.3773927 (0)	total: 3.8s	remaining: 15.2s
# 2:	learn: 727.3655804	test: 727.0297130	best: 7.3773927 (0)	total: 5.98s	remaining: 14s
# 3:	learn: 1072.3996559	test: 1075.3474710	best: 7.3773927 (0)	total: 8.02s	remaining: 12s
# 4:	learn: 1172.2037320	test: 1169.7026332	best: 7.3773927 (0)	total: 9.9s	remaining: 9.9s
# 5:	learn: 1029.1224619	test: 1037.0331667	best: 7.3773927 (0)	total: 11.9s	remaining: 7.92s
# 6:	learn: 978.8528010	test: 989.3281115	best: 7.3773927 (0)	total: 14s	remaining: 6.01s
# 7:	learn: 1224.1647330	test: 1232.1467998	best: 7.3773927 (0)	total: 16s	remaining: 4.01s
# 8:	learn: 1225.9444139	test: 1232.8416169	best: 7.3773927 (0)	total: 18.1s	remaining: 2.02s
# 9:	learn: 1221.5338194	test: 1225.3299320	best: 7.3773927 (0)	total: 20.1s	remaining: 0us
#
# bestTest = 7.377392706
# bestIteration = 0
#
# 11:	loss: 7.3773927	best: 7.1289498 (9)	total: 4m 10s	remaining: 8m 20s
# 0:	learn: 6.8262435	test: 6.8733399	best: 6.8733399 (0)	total: 2.36s	remaining: 21.2s
# 1:	learn: 1915.6471127	test: 1904.5811871	best: 6.8733399 (0)	total: 4.68s	remaining: 18.7s
# 2:	learn: 1935.3590069	test: 1940.7785304	best: 6.8733399 (0)	total: 7.47s	remaining: 17.4s
# 3:	learn: 2988.7034907	test: 2990.7533710	best: 6.8733399 (0)	total: 9.82s	remaining: 14.7s
# 4:	learn: 2860.3644175	test: 2866.3438355	best: 6.8733399 (0)	total: 12.4s	remaining: 12.4s
# 5:	learn: 2694.7918837	test: 2705.2818996	best: 6.8733399 (0)	total: 14.8s	remaining: 9.84s
# 6:	learn: 2863.5461999	test: 2891.3431572	best: 6.8733399 (0)	total: 17.1s	remaining: 7.33s
# 7:	learn: 3103.2068291	test: 3138.1289137	best: 6.8733399 (0)	total: 19.6s	remaining: 4.9s
# 8:	learn: 3097.7146470	test: 3107.0521507	best: 6.8733399 (0)	total: 22s	remaining: 2.44s
# 9:	learn: 2629.5387196	test: 2639.6913066	best: 6.8733399 (0)	total: 24.4s	remaining: 0us
#
# bestTest = 6.873339874
# bestIteration = 0
#
# 12:	loss: 6.8733399	best: 6.8733399 (12)	total: 4m 34s	remaining: 8m 6s
# 0:	learn: 6.9463390	test: 6.9942698	best: 6.9942698 (0)	total: 2.42s	remaining: 21.8s
# 1:	learn: 1963.0352985	test: 1951.7515488	best: 6.9942698 (0)	total: 4.79s	remaining: 19.2s
# 2:	learn: 1977.4141735	test: 1983.8123045	best: 6.9942698 (0)	total: 7.28s	remaining: 17s
# 3:	learn: 3029.5604040	test: 3032.4346156	best: 6.9942698 (0)	total: 9.54s	remaining: 14.3s
# 4:	learn: 2918.0870148	test: 2924.7735192	best: 6.9942698 (0)	total: 12s	remaining: 12s
# 5:	learn: 2736.0980026	test: 2747.4382850	best: 6.9942698 (0)	total: 14.7s	remaining: 9.81s
# 6:	learn: 2913.0164075	test: 2942.0421531	best: 6.9942698 (0)	total: 17.3s	remaining: 7.42s
# 7:	learn: 3171.2897148	test: 3207.6845794	best: 6.9942698 (0)	total: 20.1s	remaining: 5.03s
# 8:	learn: 3146.9931840	test: 3157.2135905	best: 6.9942698 (0)	total: 22.7s	remaining: 2.53s
# 9:	learn: 2688.1528673	test: 2699.2257875	best: 6.9942698 (0)	total: 25.3s	remaining: 0us
#
# bestTest = 6.994269754
# bestIteration = 0
#
# 13:	loss: 6.9942698	best: 6.8733399 (12)	total: 5m	remaining: 7m 52s
# 0:	learn: 7.0664993	test: 7.1152645	best: 7.1152645 (0)	total: 2.49s	remaining: 22.4s
# 1:	learn: 2007.9750483	test: 1996.4556353	best: 7.1152645 (0)	total: 4.89s	remaining: 19.6s
# 2:	learn: 2019.3883460	test: 2026.6015331	best: 7.1152645 (0)	total: 7.44s	remaining: 17.4s
# 3:	learn: 3070.0570829	test: 3073.5712405	best: 7.1152645 (0)	total: 10.1s	remaining: 15.1s
# 4:	learn: 2977.7675733	test: 2984.9948459	best: 7.1152645 (0)	total: 12.5s	remaining: 12.5s
# 5:	learn: 2776.5183708	test: 2788.5551101	best: 7.1152645 (0)	total: 14.9s	remaining: 9.91s
# 6:	learn: 2959.8329850	test: 2989.9519928	best: 7.1152645 (0)	total: 17.2s	remaining: 7.38s
# 7:	learn: 3157.9416512	test: 3195.5927069	best: 7.1152645 (0)	total: 19.6s	remaining: 4.9s
# 8:	learn: 3171.7730712	test: 3182.4517864	best: 7.1152645 (0)	total: 21.9s	remaining: 2.43s
# 9:	learn: 2771.8357596	test: 2781.2004328	best: 7.1152645 (0)	total: 24.3s	remaining: 0us
#
# bestTest = 7.115264501
# bestIteration = 0
#
# 14:	loss: 7.1152645	best: 6.8733399 (12)	total: 5m 25s	remaining: 7m 35s
# 0:	learn: 6.7718457	test: 6.8185429	best: 6.8185429 (0)	total: 2.35s	remaining: 21.1s
# 1:	learn: 963.7137881	test: 958.0984346	best: 6.8185429 (0)	total: 4.62s	remaining: 18.5s
# 2:	learn: 962.9815155	test: 965.7027369	best: 6.8185429 (0)	total: 6.93s	remaining: 16.2s
# 3:	learn: 1466.0290503	test: 1466.7784115	best: 6.8185429 (0)	total: 9.5s	remaining: 14.2s
# 4:	learn: 1466.8455884	test: 1471.5209032	best: 6.8185429 (0)	total: 12s	remaining: 12s
# 5:	learn: 1317.8907776	test: 1324.0362315	best: 6.8185429 (0)	total: 14.3s	remaining: 9.52s
# 6:	learn: 1423.3918996	test: 1445.5546473	best: 6.8185429 (0)	total: 16.9s	remaining: 7.26s
# 7:	learn: 1528.1405184	test: 1545.8266663	best: 6.8185429 (0)	total: 19.6s	remaining: 4.91s
# 8:	learn: 1541.3710877	test: 1551.4584881	best: 6.8185429 (0)	total: 22s	remaining: 2.44s
# 9:	learn: 1332.1888314	test: 1337.7149580	best: 6.8185429 (0)	total: 24.3s	remaining: 0us
#
# bestTest = 6.818542867
# bestIteration = 0
#
# 15:	loss: 6.8185429	best: 6.8185429 (15)	total: 5m 50s	remaining: 7m 17s
# 0:	learn: 6.8909332	test: 6.9384574	best: 6.9384574 (0)	total: 2.28s	remaining: 20.5s
# 1:	learn: 984.5690988	test: 978.8345617	best: 6.9384574 (0)	total: 4.63s	remaining: 18.5s
# 2:	learn: 996.1000250	test: 999.7609802	best: 6.9384574 (0)	total: 7.04s	remaining: 16.4s
# 3:	learn: 1495.9993738	test: 1496.6002206	best: 6.9384574 (0)	total: 9.64s	remaining: 14.5s
# 4:	learn: 1499.0215278	test: 1498.7655622	best: 6.9384574 (0)	total: 12.1s	remaining: 12.1s
# 5:	learn: 1349.8111080	test: 1356.1212578	best: 6.9384574 (0)	total: 14.4s	remaining: 9.59s
# 6:	learn: 1464.4471023	test: 1486.0636922	best: 6.9384574 (0)	total: 16.7s	remaining: 7.16s
# 7:	learn: 1578.9309458	test: 1594.7805403	best: 6.9384574 (0)	total: 19.1s	remaining: 4.78s
# 8:	learn: 1570.8176080	test: 1578.4517246	best: 6.9384574 (0)	total: 21.5s	remaining: 2.39s
# 9:	learn: 1381.6103637	test: 1387.9374312	best: 6.9384574 (0)	total: 24s	remaining: 0us
#
# bestTest = 6.938457412
# bestIteration = 0
#
# 16:	loss: 6.9384574	best: 6.8185429 (15)	total: 6m 14s	remaining: 6m 58s
# 0:	learn: 7.0100871	test: 7.0584385	best: 7.0584385 (0)	total: 2.39s	remaining: 21.5s
# 1:	learn: 1004.8779713	test: 999.0249149	best: 7.0584385 (0)	total: 4.71s	remaining: 18.8s
# 2:	learn: 1021.0260899	test: 1024.9615110	best: 7.0584385 (0)	total: 7.07s	remaining: 16.5s
# 3:	learn: 1433.0576326	test: 1436.1937110	best: 7.0584385 (0)	total: 9.7s	remaining: 14.5s
# 4:	learn: 1433.3965114	test: 1435.9238405	best: 7.0584385 (0)	total: 12s	remaining: 12s
# 5:	learn: 1353.5821306	test: 1362.5562128	best: 7.0584385 (0)	total: 14.4s	remaining: 9.59s
# 6:	learn: 1335.8587050	test: 1353.5505157	best: 7.0584385 (0)	total: 16.8s	remaining: 7.22s
# 7:	learn: 1556.0245618	test: 1572.8407289	best: 7.0584385 (0)	total: 19.1s	remaining: 4.78s
# 8:	learn: 1731.2183713	test: 1739.8470837	best: 7.0584385 (0)	total: 21.5s	remaining: 2.38s
# 9:	learn: 1180.5880519	test: 1189.0992283	best: 7.0584385 (0)	total: 23.8s	remaining: 0us
#
# bestTest = 7.058438522
# bestIteration = 0
#
# 17:	loss: 7.0584385	best: 6.8185429 (15)	total: 6m 38s	remaining: 6m 38s
# 0:	learn: 6.7193897	test: 6.7656870	best: 6.7656870 (0)	total: 2.34s	remaining: 21s
# 1:	learn: 640.9821763	test: 637.2168322	best: 6.7656870 (0)	total: 4.57s	remaining: 18.3s
# 2:	learn: 656.3591970	test: 658.7539209	best: 6.7656870 (0)	total: 7.07s	remaining: 16.5s
# 3:	learn: 927.6176091	test: 929.6173293	best: 6.7656870 (0)	total: 9.78s	remaining: 14.7s
# 4:	learn: 882.8187976	test: 885.5380381	best: 6.7656870 (0)	total: 12.1s	remaining: 12.1s
# 5:	learn: 914.0555962	test: 918.9226080	best: 6.7656870 (0)	total: 14.5s	remaining: 9.67s
# 6:	learn: 880.7303391	test: 892.4211485	best: 6.7656870 (0)	total: 16.8s	remaining: 7.21s
# 7:	learn: 998.3963545	test: 1009.7438617	best: 6.7656870 (0)	total: 19.2s	remaining: 4.8s
# 8:	learn: 1072.2594706	test: 1076.6528472	best: 6.7656870 (0)	total: 21.5s	remaining: 2.39s
# 9:	learn: 726.3891662	test: 732.7791443	best: 6.7656870 (0)	total: 24.2s	remaining: 0us
#
# bestTest = 6.765686968
# bestIteration = 0
#
# 18:	loss: 6.7656870	best: 6.7656870 (18)	total: 7m 3s	remaining: 6m 18s
# 0:	learn: 6.8375030	test: 6.8846200	best: 6.8846200 (0)	total: 2.39s	remaining: 21.5s
# 1:	learn: 655.4489647	test: 651.5745529	best: 6.8846200 (0)	total: 4.96s	remaining: 19.9s
# 2:	learn: 700.7391169	test: 701.3866650	best: 6.8846200 (0)	total: 7.69s	remaining: 17.9s
# 3:	learn: 1017.7956126	test: 1016.3246661	best: 6.8846200 (0)	total: 10.4s	remaining: 15.6s
# 4:	learn: 932.8913570	test: 935.9311354	best: 6.8846200 (0)	total: 12.9s	remaining: 12.9s
# 5:	learn: 889.2601123	test: 893.1005663	best: 6.8846200 (0)	total: 15.5s	remaining: 10.3s
# 6:	learn: 977.5098900	test: 991.5577839	best: 6.8846200 (0)	total: 17.8s	remaining: 7.64s
# 7:	learn: 1046.5013419	test: 1057.4459095	best: 6.8846200 (0)	total: 20.2s	remaining: 5.04s
# 8:	learn: 1084.9890889	test: 1090.1643052	best: 6.8846200 (0)	total: 22.5s	remaining: 2.5s
# 9:	learn: 930.7678053	test: 935.0658341	best: 6.8846200 (0)	total: 24.8s	remaining: 0us
#
# bestTest = 6.884619986
# bestIteration = 0
#
# 19:	loss: 6.8846200	best: 6.7656870 (18)	total: 7m 28s	remaining: 5m 58s
# 0:	learn: 6.9556844	test: 7.0036213	best: 7.0036213 (0)	total: 2.28s	remaining: 20.5s
# 1:	learn: 670.5976981	test: 666.5890777	best: 7.0036213 (0)	total: 4.74s	remaining: 18.9s
# 2:	learn: 716.0607822	test: 716.6696466	best: 7.0036213 (0)	total: 7.11s	remaining: 16.6s
# 3:	learn: 1033.1265350	test: 1031.5370696	best: 7.0036213 (0)	total: 9.86s	remaining: 14.8s
# 4:	learn: 966.0233087	test: 968.7584268	best: 7.0036213 (0)	total: 12.2s	remaining: 12.2s
# 5:	learn: 904.4052393	test: 908.2136680	best: 7.0036213 (0)	total: 14.6s	remaining: 9.71s
# 6:	learn: 998.6720108	test: 1012.8757184	best: 7.0036213 (0)	total: 16.9s	remaining: 7.25s
# 7:	learn: 1064.6385072	test: 1075.6586340	best: 7.0036213 (0)	total: 19.3s	remaining: 4.82s
# 8:	learn: 1094.3137083	test: 1099.5460410	best: 7.0036213 (0)	total: 22s	remaining: 2.44s
# 9:	learn: 946.9236664	test: 951.0285727	best: 7.0036213 (0)	total: 24.4s	remaining: 0us
#
# bestTest = 7.003621319
# bestIteration = 0
#
# 20:	loss: 7.0036213	best: 6.7656870 (18)	total: 7m 53s	remaining: 5m 38s
# 0:	learn: 6.6686381	test: 6.7145404	best: 6.7145404 (0)	total: 2.3s	remaining: 20.7s
# 1:	learn: 480.4177965	test: 477.5426849	best: 6.7145404 (0)	total: 4.61s	remaining: 18.4s
# 2:	learn: 519.3521078	test: 519.9099957	best: 6.7145404 (0)	total: 6.88s	remaining: 16.1s
# 3:	learn: 752.7061095	test: 751.6917382	best: 6.7145404 (0)	total: 9.19s	remaining: 13.8s
# 4:	learn: 699.8140381	test: 701.9489224	best: 6.7145404 (0)	total: 11.8s	remaining: 11.8s
# 5:	learn: 634.3206874	test: 637.2769725	best: 6.7145404 (0)	total: 14.1s	remaining: 9.42s
# 6:	learn: 723.0236389	test: 733.6249049	best: 6.7145404 (0)	total: 16.5s	remaining: 7.07s
# 7:	learn: 764.7718001	test: 772.7242401	best: 6.7145404 (0)	total: 18.8s	remaining: 4.69s
# 8:	learn: 792.6592522	test: 796.5005711	best: 6.7145404 (0)	total: 21.2s	remaining: 2.35s
# 9:	learn: 687.4344636	test: 690.3530269	best: 6.7145404 (0)	total: 23.8s	remaining: 0us
#
# bestTest = 6.714540392
# bestIteration = 0
#
# 21:	loss: 6.7145404	best: 6.7145404 (21)	total: 8m 17s	remaining: 5m 16s
# 0:	learn: 6.7858066	test: 6.8325215	best: 6.8325215 (0)	total: 2.37s	remaining: 21.3s
# 1:	learn: 491.6904223	test: 488.7150369	best: 6.8325215 (0)	total: 5.04s	remaining: 20.2s
# 2:	learn: 528.7825232	test: 529.3695002	best: 6.8325215 (0)	total: 8.74s	remaining: 20.4s
# 3:	learn: 762.7507721	test: 761.7032842	best: 6.8325215 (0)	total: 11.2s	remaining: 16.7s
# 4:	learn: 714.3061552	test: 716.4546449	best: 6.8325215 (0)	total: 13.9s	remaining: 13.9s
# 5:	learn: 646.2450810	test: 649.2747783	best: 6.8325215 (0)	total: 16.2s	remaining: 10.8s
# 6:	learn: 737.2721738	test: 748.1039033	best: 6.8325215 (0)	total: 18.6s	remaining: 7.97s
# 7:	learn: 776.7856456	test: 784.8966595	best: 6.8325215 (0)	total: 21.2s	remaining: 5.29s
# 8:	learn: 806.8052600	test: 810.7606510	best: 6.8325215 (0)	total: 23.5s	remaining: 2.61s
# 9:	learn: 696.0869322	test: 699.0385000	best: 6.8325215 (0)	total: 26.1s	remaining: 0us
#
# bestTest = 6.832521518
# bestIteration = 0
#
# 22:	loss: 6.8325215	best: 6.7145404 (21)	total: 8m 44s	remaining: 4m 56s
# 0:	learn: 6.9030451	test: 6.9505728	best: 6.9505728 (0)	total: 2.32s	remaining: 20.9s
# 1:	learn: 502.7997650	test: 499.7218271	best: 6.9505728 (0)	total: 4.64s	remaining: 18.6s
# 2:	learn: 536.0342502	test: 536.7413058	best: 6.9505728 (0)	total: 6.97s	remaining: 16.3s
# 3:	learn: 771.1573175	test: 769.9492962	best: 6.9505728 (0)	total: 9.63s	remaining: 14.5s
# 4:	learn: 725.5014197	test: 727.6486123	best: 6.9505728 (0)	total: 12.5s	remaining: 12.5s
# 5:	learn: 655.1199958	test: 658.2874969	best: 6.9505728 (0)	total: 14.8s	remaining: 9.84s
# 6:	learn: 744.1981920	test: 755.5863409	best: 6.9505728 (0)	total: 17.1s	remaining: 7.35s
# 7:	learn: 786.5037347	test: 794.5826020	best: 6.9505728 (0)	total: 19.4s	remaining: 4.86s
# 8:	learn: 809.8435741	test: 813.7889673	best: 6.9505728 (0)	total: 21.9s	remaining: 2.43s
# 9:	learn: 704.9862615	test: 707.9761280	best: 6.9505728 (0)	total: 24.3s	remaining: 0us
#
# bestTest = 6.950572764
# bestIteration = 0
#
# 23:	loss: 6.9505728	best: 6.7145404 (21)	total: 9m 8s	remaining: 4m 34s
# 0:	learn: 7.2606656	test: 7.3296647	best: 7.3296647 (0)	total: 3.38s	remaining: 30.4s
# 1:	learn: 1873.2697507	test: 1863.8485758	best: 7.3296647 (0)	total: 6.67s	remaining: 26.7s
# 2:	learn: 1763.0938675	test: 1775.8576606	best: 7.3296647 (0)	total: 10.7s	remaining: 25s
# 3:	learn: 2059.8072700	test: 2075.9334777	best: 7.3296647 (0)	total: 13.9s	remaining: 20.8s
# 4:	learn: 1785.4790802	test: 1785.8391988	best: 7.3296647 (0)	total: 17.2s	remaining: 17.2s
# 5:	learn: 1566.5663641	test: 1581.4770331	best: 7.3296647 (0)	total: 20.5s	remaining: 13.7s
# 6:	learn: 1952.4937132	test: 1959.4261132	best: 7.3296647 (0)	total: 23.7s	remaining: 10.2s
# 7:	learn: 1790.3748576	test: 1794.3002099	best: 7.3296647 (0)	total: 27s	remaining: 6.75s
# 8:	learn: 1954.5129098	test: 1962.5715089	best: 7.3296647 (0)	total: 30.3s	remaining: 3.37s
# 9:	learn: 1833.8863770	test: 1839.1854971	best: 7.3296647 (0)	total: 33.7s	remaining: 0us
#
# bestTest = 7.329664723
# bestIteration = 0
#
# 24:	loss: 7.3296647	best: 6.7145404 (21)	total: 9m 43s	remaining: 4m 16s
# 0:	learn: 7.3891990	test: 7.4594241	best: 7.4594241 (0)	total: 3.29s	remaining: 29.6s
# 1:	learn: 1916.9826118	test: 1907.4146600	best: 7.4594241 (0)	total: 6.38s	remaining: 25.5s
# 2:	learn: 1798.0084367	test: 1811.0747056	best: 7.4594241 (0)	total: 10.3s	remaining: 24.2s
# 3:	learn: 2091.8262175	test: 2108.2136839	best: 7.4594241 (0)	total: 13.3s	remaining: 20s
# 4:	learn: 1816.1336735	test: 1816.7602809	best: 7.4594241 (0)	total: 16.7s	remaining: 16.7s
# 5:	learn: 1581.7363431	test: 1597.1228188	best: 7.4594241 (0)	total: 19.9s	remaining: 13.3s
# 6:	learn: 1943.6313131	test: 1950.5458873	best: 7.4594241 (0)	total: 23s	remaining: 9.88s
# 7:	learn: 1835.4504910	test: 1838.2816155	best: 7.4594241 (0)	total: 26.2s	remaining: 6.56s
# 8:	learn: 2018.6194210	test: 2024.9300281	best: 7.4594241 (0)	total: 29.4s	remaining: 3.27s
# 9:	learn: 1791.0759867	test: 1795.2664329	best: 7.4594241 (0)	total: 32.7s	remaining: 0us
#
# bestTest = 7.45942407
# bestIteration = 0
#
# 25:	loss: 7.4594241	best: 6.7145404 (21)	total: 10m 16s	remaining: 3m 57s
# 0:	learn: 7.5177675	test: 7.5892186	best: 7.5892186 (0)	total: 3.08s	remaining: 27.7s
# 1:	learn: 1958.6175589	test: 1948.8844280	best: 7.5892186 (0)	total: 6.21s	remaining: 24.8s
# 2:	learn: 1832.3964426	test: 1845.7743081	best: 7.5892186 (0)	total: 9.89s	remaining: 23.1s
# 3:	learn: 2123.2624964	test: 2139.8972718	best: 7.5892186 (0)	total: 13.2s	remaining: 19.8s
# 4:	learn: 1874.4188185	test: 1875.2233788	best: 7.5892186 (0)	total: 16.6s	remaining: 16.6s
# 5:	learn: 1622.4112902	test: 1638.9140535	best: 7.5892186 (0)	total: 19.6s	remaining: 13.1s
# 6:	learn: 1991.3412173	test: 1998.9272674	best: 7.5892186 (0)	total: 22.8s	remaining: 9.76s
# 7:	learn: 1848.9019967	test: 1854.0005058	best: 7.5892186 (0)	total: 25.9s	remaining: 6.47s
# 8:	learn: 2023.0178971	test: 2025.9742077	best: 7.5892186 (0)	total: 29.1s	remaining: 3.23s
# 9:	learn: 1938.7439288	test: 1949.7823520	best: 7.5892186 (0)	total: 32.2s	remaining: 0us
#
# bestTest = 7.589218615
# bestIteration = 0
#
# 26:	loss: 7.5892186	best: 6.7145404 (21)	total: 10m 48s	remaining: 3m 36s
# 0:	learn: 7.1795278	test: 7.2477181	best: 7.2477181 (0)	total: 3.29s	remaining: 29.6s
# 1:	learn: 937.6411614	test: 932.9373798	best: 7.2477181 (0)	total: 6.53s	remaining: 26.1s
# 2:	learn: 888.8718748	test: 895.4755174	best: 7.2477181 (0)	total: 10.3s	remaining: 24.1s
# 3:	learn: 1008.3839845	test: 1017.2175191	best: 7.2477181 (0)	total: 14.5s	remaining: 21.7s
# 4:	learn: 900.4517784	test: 900.4916296	best: 7.2477181 (0)	total: 18.5s	remaining: 18.5s
# 5:	learn: 701.1988288	test: 707.3891333	best: 7.2477181 (0)	total: 22.6s	remaining: 15.1s
# 6:	learn: 866.6159286	test: 870.6555897	best: 7.2477181 (0)	total: 26.8s	remaining: 11.5s
# 7:	learn: 918.9334623	test: 921.3809299	best: 7.2477181 (0)	total: 31.4s	remaining: 7.84s
# 8:	learn: 839.4661671	test: 845.8572181	best: 7.2477181 (0)	total: 35.3s	remaining: 3.92s
# 9:	learn: 900.6487318	test: 908.0430471	best: 7.2477181 (0)	total: 39.4s	remaining: 0us
#
# bestTest = 7.24771805
# bestIteration = 0
#
# 27:	loss: 7.2477181	best: 6.7145404 (21)	total: 11m 28s	remaining: 3m 16s
# 0:	learn: 7.3065858	test: 7.3759876	best: 7.3759876 (0)	total: 4.02s	remaining: 36.2s
# 1:	learn: 956.5467865	test: 951.7484879	best: 7.3759876 (0)	total: 8.21s	remaining: 32.9s
# 2:	learn: 907.6068689	test: 914.4728219	best: 7.3759876 (0)	total: 12.2s	remaining: 28.5s
# 3:	learn: 1024.1578834	test: 1031.8571070	best: 7.3759876 (0)	total: 16.3s	remaining: 24.4s
# 4:	learn: 950.2913073	test: 952.2295291	best: 7.3759876 (0)	total: 20.7s	remaining: 20.7s
# 5:	learn: 706.2453100	test: 712.5229780	best: 7.3759876 (0)	total: 24.8s	remaining: 16.6s
# 6:	learn: 890.6269328	test: 897.1163356	best: 7.3759876 (0)	total: 28.8s	remaining: 12.3s
# 7:	learn: 943.6626551	test: 944.8517185	best: 7.3759876 (0)	total: 32.2s	remaining: 8.06s
# 8:	learn: 827.9372676	test: 834.1976868	best: 7.3759876 (0)	total: 36.3s	remaining: 4.03s
# 9:	learn: 895.6918076	test: 899.6612245	best: 7.3759876 (0)	total: 40.3s	remaining: 0us
#
# bestTest = 7.375987578
# bestIteration = 0
#
# 28:	loss: 7.3759876	best: 6.7145404 (21)	total: 12m 9s	remaining: 2m 56s
# 0:	learn: 7.4336799	test: 7.5042932	best: 7.5042932 (0)	total: 3.38s	remaining: 30.4s
# 1:	learn: 974.7964538	test: 969.8997524	best: 7.5042932 (0)	total: 6.58s	remaining: 26.3s
# 2:	learn: 927.2418653	test: 934.2747128	best: 7.5042932 (0)	total: 10.7s	remaining: 25.1s
# 3:	learn: 1041.1688889	test: 1048.6286756	best: 7.5042932 (0)	total: 15.5s	remaining: 23.2s
# 4:	learn: 961.4881307	test: 963.2398989	best: 7.5042932 (0)	total: 20.8s	remaining: 20.8s
# 5:	learn: 798.7567260	test: 809.1646107	best: 7.5042932 (0)	total: 25.2s	remaining: 16.8s
# 6:	learn: 966.8910602	test: 970.0287079	best: 7.5042932 (0)	total: 29.5s	remaining: 12.7s
# 7:	learn: 1038.2316674	test: 1039.4252398	best: 7.5042932 (0)	total: 34s	remaining: 8.5s
# 8:	learn: 1089.7390797	test: 1094.0662078	best: 7.5042932 (0)	total: 38.3s	remaining: 4.25s
# 9:	learn: 872.1511573	test: 877.2849889	best: 7.5042932 (0)	total: 42.3s	remaining: 0us
#
# bestTest = 7.504293239
# bestIteration = 0
#
# 29:	loss: 7.5042932	best: 6.7145404 (21)	total: 12m 52s	remaining: 2m 34s
# 0:	learn: 7.1020687	test: 7.1694877	best: 7.1694877 (0)	total: 4.27s	remaining: 38.5s
# 1:	learn: 620.9068306	test: 617.7704568	best: 7.1694877 (0)	total: 8.53s	remaining: 34.1s
# 2:	learn: 597.1874418	test: 601.5963024	best: 7.1694877 (0)	total: 12.5s	remaining: 29.2s
# 3:	learn: 640.8486777	test: 645.4134198	best: 7.1694877 (0)	total: 16.7s	remaining: 25s
# 4:	learn: 703.6783385	test: 708.7070596	best: 7.1694877 (0)	total: 20.9s	remaining: 20.9s
# 5:	learn: 622.6095174	test: 629.1553042	best: 7.1694877 (0)	total: 25s	remaining: 16.7s
# 6:	learn: 715.7540370	test: 720.4973013	best: 7.1694877 (0)	total: 29.1s	remaining: 12.5s
# 7:	learn: 663.8242792	test: 664.7736254	best: 7.1694877 (0)	total: 33.6s	remaining: 8.4s
# 8:	learn: 673.3487147	test: 674.9389185	best: 7.1694877 (0)	total: 37.9s	remaining: 4.21s
# 9:	learn: 554.2518925	test: 555.4076282	best: 7.1694877 (0)	total: 42.1s	remaining: 0us
#
# bestTest = 7.169487726
# bestIteration = 0
#
# 30:	loss: 7.1694877	best: 6.7145404 (21)	total: 13m 34s	remaining: 2m 11s
# 0:	learn: 7.2277162	test: 7.2963330	best: 7.2963330 (0)	total: 3.99s	remaining: 35.9s
# 1:	learn: 632.7497025	test: 629.5480897	best: 7.2963330 (0)	total: 7.98s	remaining: 31.9s
# 2:	learn: 611.1137624	test: 615.6251293	best: 7.2963330 (0)	total: 12.4s	remaining: 29s
# 3:	learn: 682.9147577	test: 686.2225139	best: 7.2963330 (0)	total: 16.5s	remaining: 24.7s
# 4:	learn: 720.3070411	test: 724.9211811	best: 7.2963330 (0)	total: 21.2s	remaining: 21.2s
# 5:	learn: 647.8415764	test: 654.7078962	best: 7.2963330 (0)	total: 26s	remaining: 17.3s
# 6:	learn: 754.5730028	test: 758.9879381	best: 7.2963330 (0)	total: 29.8s	remaining: 12.8s
# 7:	learn: 667.5615585	test: 669.4518161	best: 7.2963330 (0)	total: 33.6s	remaining: 8.39s
# 8:	learn: 677.4545738	test: 678.9693806	best: 7.2963330 (0)	total: 38.7s	remaining: 4.3s
# 9:	learn: 581.3610602	test: 582.3782809	best: 7.2963330 (0)	total: 42.7s	remaining: 0us
#
# bestTest = 7.296332997
# bestIteration = 0
#
# 31:	loss: 7.2963330	best: 6.7145404 (21)	total: 14m 18s	remaining: 1m 47s
# 0:	learn: 7.3534009	test: 7.4232154	best: 7.4232154 (0)	total: 3.96s	remaining: 35.6s
# 1:	learn: 644.2865141	test: 641.0190829	best: 7.4232154 (0)	total: 7.95s	remaining: 31.8s
# 2:	learn: 624.6220856	test: 629.2571425	best: 7.4232154 (0)	total: 12.2s	remaining: 28.5s
# 3:	learn: 698.7131486	test: 701.8750598	best: 7.4232154 (0)	total: 16.1s	remaining: 24.2s
# 4:	learn: 749.6608082	test: 753.0893823	best: 7.4232154 (0)	total: 20.1s	remaining: 20.1s
# 5:	learn: 654.3907741	test: 661.7197202	best: 7.4232154 (0)	total: 24.1s	remaining: 16s
# 6:	learn: 802.2610791	test: 806.8340909	best: 7.4232154 (0)	total: 28.4s	remaining: 12.2s
# 7:	learn: 673.4764061	test: 675.8989900	best: 7.4232154 (0)	total: 32.3s	remaining: 8.09s
# 8:	learn: 828.3465449	test: 825.7123222	best: 7.4232154 (0)	total: 36.2s	remaining: 4.03s
# 9:	learn: 651.6136288	test: 650.2439473	best: 7.4232154 (0)	total: 40.1s	remaining: 0us
#
# bestTest = 7.423215383
# bestIteration = 0
#
# 32:	loss: 7.4232154	best: 6.7145404 (21)	total: 14m 58s	remaining: 1m 21s
# 0:	learn: 7.0278444	test: 7.0945276	best: 7.0945276 (0)	total: 3.99s	remaining: 35.9s
# 1:	learn: 247.5162876	test: 247.5814994	best: 7.0945276 (0)	total: 7.85s	remaining: 31.4s
# 2:	learn: 407.5247795	test: 415.3546229	best: 7.0945276 (0)	total: 11.7s	remaining: 27.3s
# 3:	learn: 369.4174627	test: 378.9472739	best: 7.0945276 (0)	total: 15.5s	remaining: 23.2s
# 4:	learn: 364.3582339	test: 372.2329927	best: 7.0945276 (0)	total: 20.2s	remaining: 20.2s
# 5:	learn: 483.8928469	test: 490.0844657	best: 7.0945276 (0)	total: 24.5s	remaining: 16.3s
# 6:	learn: 376.6981111	test: 385.5702272	best: 7.0945276 (0)	total: 28.6s	remaining: 12.3s
# 7:	learn: 408.3748742	test: 413.8645799	best: 7.0945276 (0)	total: 32.4s	remaining: 8.11s
# 8:	learn: 376.1944902	test: 380.4043980	best: 7.0945276 (0)	total: 36.8s	remaining: 4.08s
# 9:	learn: 313.3557239	test: 316.0568928	best: 7.0945276 (0)	total: 40.7s	remaining: 0us
#
# bestTest = 7.094527607
# bestIteration = 0
#
# 33:	loss: 7.0945276	best: 6.7145404 (21)	total: 15m 39s	remaining: 55.3s
# 0:	learn: 7.1521384	test: 7.2200062	best: 7.2200062 (0)	total: 3.97s	remaining: 35.7s
# 1:	learn: 470.5248562	test: 468.1294273	best: 7.2200062 (0)	total: 7.9s	remaining: 31.6s
# 2:	learn: 463.2724072	test: 466.6121589	best: 7.2200062 (0)	total: 12.2s	remaining: 28.4s
# 3:	learn: 518.8060601	test: 520.5219212	best: 7.2200062 (0)	total: 16.1s	remaining: 24.2s
# 4:	learn: 540.2035325	test: 542.6022601	best: 7.2200062 (0)	total: 20.1s	remaining: 20.1s
# 5:	learn: 420.3356601	test: 425.2027915	best: 7.2200062 (0)	total: 24.6s	remaining: 16.4s
# 6:	learn: 520.2089859	test: 524.2623158	best: 7.2200062 (0)	total: 28.8s	remaining: 12.3s
# 7:	learn: 455.9729388	test: 458.1146616	best: 7.2200062 (0)	total: 33s	remaining: 8.26s
# 8:	learn: 520.5391775	test: 520.2253109	best: 7.2200062 (0)	total: 36.9s	remaining: 4.1s
# 9:	learn: 421.7873206	test: 424.1960647	best: 7.2200062 (0)	total: 41.3s	remaining: 0us
#
# bestTest = 7.220006194
# bestIteration = 0
#
# 34:	loss: 7.2200062	best: 6.7145404 (21)	total: 16m 21s	remaining: 28s
# 0:	learn: 7.2764706	test: 7.3455229	best: 7.3455229 (0)	total: 4.18s	remaining: 37.6s
# 1:	learn: 479.0282637	test: 476.5839820	best: 7.3455229 (0)	total: 8.18s	remaining: 32.7s
# 2:	learn: 473.7901226	test: 477.2027950	best: 7.3455229 (0)	total: 12.6s	remaining: 29.4s
# 3:	learn: 528.3224322	test: 530.0970402	best: 7.3455229 (0)	total: 17.5s	remaining: 26.3s
# 4:	learn: 549.0947897	test: 551.5286433	best: 7.3455229 (0)	total: 23.1s	remaining: 23.1s
# 5:	learn: 425.8887195	test: 430.8232899	best: 7.3455229 (0)	total: 28.2s	remaining: 18.8s
# 6:	learn: 527.8369113	test: 532.1623516	best: 7.3455229 (0)	total: 32.9s	remaining: 14.1s
# 7:	learn: 467.7030659	test: 469.6979586	best: 7.3455229 (0)	total: 38s	remaining: 9.51s
# 8:	learn: 522.7814728	test: 522.4380185	best: 7.3455229 (0)	total: 42.6s	remaining: 4.73s
# 9:	learn: 401.8795546	test: 404.7416874	best: 7.3455229 (0)	total: 46.3s	remaining: 0us
#
# bestTest = 7.345522921
# bestIteration = 0
#
# 35:	loss: 7.3455229	best: 6.7145404 (21)	total: 17m 8s	remaining: 0us
# Estimating final quality...
# Training on fold [0/5]
#  Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than parts count=5
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# <ipython-input-16-4019b3ef77cf> in <module>
#       5 }
#       6
# ----> 7 cb_grid = catboost_model.grid_search(cb_params, cv=5, X=x, y=y, verbose=True)
#       8
#       9 print (cb_grid["params"])
#
# E:\anaconda\lib\site-packages\catboost\core.py in grid_search(self, param_grid, X, y, cv, partition_random_seed, calc_cv_statistics, search_by_train_test_split, refit, shuffle, stratified, train_size, verbose, plot, log_cout, log_cerr)
#    3823                     raise TypeError('Parameter grid value is not iterable (key={!r}, value={!r})'.format(key, grid[key]))
#    3824
# -> 3825         return self._tune_hyperparams(
#    3826             param_grid=param_grid, X=X, y=y, cv=cv, n_iter=-1,
#    3827             partition_random_seed=partition_random_seed, calc_cv_statistics=calc_cv_statistics,
#
# E:\anaconda\lib\site-packages\catboost\core.py in _tune_hyperparams(self, param_grid, X, y, cv, n_iter, partition_random_seed, calc_cv_statistics, search_by_train_test_split, refit, shuffle, stratified, train_size, verbose, plot, log_cout, log_cerr)
#    3720
#    3721         with log_fixup(log_cout, log_cerr), plot_wrapper(plot, [_get_train_dir(params)]):
# -> 3722             cv_result = self._object._tune_hyperparams(
#    3723                 param_grid, train_params["train_pool"], params, n_iter,
#    3724                 fold_count, partition_random_seed, shuffle, stratified, train_size,
#
# _catboost.pyx in _catboost._CatBoost._tune_hyperparams()
#
# _catboost.pyx in _catboost._CatBoost._tune_hyperparams()
#
# CatBoostError: C:/Program Files (x86)/Go Agent/pipelines/BuildMaster/catboost.git/catboost/private/libs/target/target_converter.cpp:226: Unknown class label: "4"

# %%
catboost_model.fit(train_dataset)
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# 0:	learn: 7.7490464	total: 3.58s	remaining: 32.2s
# 1:	learn: 680.3431166	total: 6.95s	remaining: 27.8s
# 2:	learn: 883.3882592	total: 11.1s	remaining: 25.9s
# 3:	learn: 1800.3032539	total: 15.2s	remaining: 22.9s
# 4:	learn: 1438.6308668	total: 19.4s	remaining: 19.4s
# 5:	learn: 1483.0781330	total: 23s	remaining: 15.4s
# 6:	learn: 947.9335749	total: 26.9s	remaining: 11.5s
# 7:	learn: 875.6136442	total: 30.4s	remaining: 7.59s
# 8:	learn: 1232.1083881	total: 34.2s	remaining: 3.8s
# 9:	learn: 908.7140118	total: 37.9s	remaining: 0us

# %% [markdown]
# ### Обогащение тестовых данных

# %%
test_data = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_test.tsv.gz', sep='\t')
test_data.head()
# Out:
#    building_series_id  site_id  parking  build_year  expect_demolition  \
# 0              663294        0  UNKNOWN        1971              False
# 1              712125        0  UNKNOWN        1986              False
# 2                   0        0  UNKNOWN        2014              False
# 3                   0        0  UNKNOWN        2001              False
# 4             1564812        0  UNKNOWN        2019              False
#
#                                           main_image   latitude  total_area  \
# 0  //avatars.mds.yandex.net/get-realty/1900763/ad...  55.795704   36.000000
# 1  //avatars.mds.yandex.net/get-realty/1583116/ad...  55.605583   40.000000
# 2  //avatars.mds.yandex.net/get-realty/2124710/ad...  55.925560   25.000000
# 3  //avatars.mds.yandex.net/get-realty/2958378/ad...  55.432522   42.000000
# 4  //avatars.mds.yandex.net/get-realty/2732616/ad...  55.917530   73.300003
#
#    ceiling_height  rooms  ...  kitchen_area         day  public  longitude  \
# 0            2.64      1  ...           0.0  2020-01-25    True  37.602478
# 1            2.48      1  ...          10.0  2019-11-19    True  37.743679
# 2            0.00      0  ...           0.0  2020-01-11    True  37.862965
# 3            0.00      1  ...          10.0  2020-01-27    True  37.544224
# 4            2.80      3  ...          10.2  2020-03-04   False  37.411098
#
#    price  flats_count  building_type     balcony locality_name     renovation
# 0  40000           80          PANEL     UNKNOWN        Москва        UNKNOWN
# 1  25000          222          PANEL      LOGGIA        Москва  COSMETIC_DONE
# 2  19000          179        MONOLIT      LOGGIA       Королёв  COSMETIC_DONE
# 3  20000            0          PANEL      LOGGIA      Подольск  COSMETIC_DONE
# 4  68000            0        MONOLIT  TWO_LOGGIA         Химки           EURO
#
# [5 rows x 30 columns]

# %% [markdown]
# Зависимость срока экспозиции от количества объявлений в день. Возможно, имеет смысл просто взять логарифм от числа объявлений в день - и использовать его для кластеризации/классификации

# %%
train = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_train.tsv.gz', sep='\t')
train_day_count = train.groupby("day").count()["target"]
train_day_mean = train.groupby("day").mean()["target"]
train["day_count"] = train["day"].apply(lambda x:train_day_count.loc[x])
train["day_mean"] = train["day"].apply(lambda x:train_day_mean.loc[x])

# %%
x = np.array(train[train["day_count"]>max(train_day_count)-1]["day_count"]).reshape(-1, 1)
y = train[train["day_count"]>max(train_day_count)-1]["day_mean"]
day_model = LinearRegression().fit(x, y)

# %%
test_day_count = test_data.groupby("day").count()["total_area"]
test_data["day_count"] = test_data["day"].apply(lambda x:test_day_count.loc[x])
test_data["day_mean"] = day_model.predict(np.array(test_data["day_count"]).reshape(-1, 1))
test_data.loc[test_data["day_count"]<max(test_data["day_count"]),"day_mean"] = train_day_mean.mean()

# %%
test_data.head(30)
# Out:
#     building_series_id  site_id  parking  build_year  expect_demolition  \
# 0               663294        0  UNKNOWN        1971              False
# 1               712125        0  UNKNOWN        1986              False
# 2                    0        0  UNKNOWN        2014              False
# 3                    0        0  UNKNOWN        2001              False
# 4              1564812        0  UNKNOWN        2019              False
# 5              1564812        0  UNKNOWN        1961              False
# 6              1564812        0  UNKNOWN        2016              False
# 7              1564812        0  UNKNOWN        1952              False
# 8              1564812        0  UNKNOWN        1966              False
# 9               663320        0  UNKNOWN        2005              False
# 10                   0        0  UNKNOWN        1980              False
# 11             1564812        0  UNKNOWN        2007              False
# 12             1564812        0  UNKNOWN        2007              False
# 13                   0        0  UNKNOWN        1971              False
# 14             1564812        0  UNKNOWN        2003              False
# 15              663278        0  UNKNOWN        1977              False
# 16              712156        0  UNKNOWN           0              False
# 17                   0        0  UNKNOWN        2008              False
# 18                   0        0  UNKNOWN        1993              False
# 19                   0        0  UNKNOWN        1996              False
# 20                   0        0  UNKNOWN        1878              False
# 21             1564812        0  UNKNOWN        2007              False
# 22             1564812        0  UNKNOWN        2018              False
# 23             1564812        0  UNKNOWN        2000              False
# 24              712125        0  UNKNOWN        1973              False
# 25              663320        0  UNKNOWN        2018              False
# 26             1564812        0  UNKNOWN           0              False
# 27              663294        0  UNKNOWN        1968              False
# 28              663278        0  UNKNOWN        1960               True
# 29                   0        0  UNKNOWN        1966              False
#
#                                            main_image   latitude  total_area  \
# 0   //avatars.mds.yandex.net/get-realty/1900763/ad...  55.795704   36.000000
# 1   //avatars.mds.yandex.net/get-realty/1583116/ad...  55.605583   40.000000
# 2   //avatars.mds.yandex.net/get-realty/2124710/ad...  55.925560   25.000000
# 3   //avatars.mds.yandex.net/get-realty/2958378/ad...  55.432522   42.000000
# 4   //avatars.mds.yandex.net/get-realty/2732616/ad...  55.917530   73.300003
# 5   //avatars.mds.yandex.net/get-realty/1651606/ad...  55.677845   32.000000
# 6   //avatars.mds.yandex.net/get-realty/2355710/ad...  55.842464   30.000000
# 7   //avatars.mds.yandex.net/get-realty/2090636/ad...  55.779575   40.000000
# 8   //avatars.mds.yandex.net/get-realty/2353363/ad...  55.765087   48.000000
# 9   //avatars.mds.yandex.net/get-realty/2771165/ad...  55.886742   52.000000
# 10  //avatars.mds.yandex.net/get-realty/1935632/ad...  55.867043   19.000000
# 11  //avatars.mds.yandex.net/get-realty/1982757/ad...  55.905396  107.000000
# 12  //avatars.mds.yandex.net/get-realty/2001447/ad...  55.947136   40.299999
# 13  //avatars.mds.yandex.net/get-realty/1968890/ad...  55.771656   32.000000
# 14  //avatars.mds.yandex.net/get-realty/2068874/ad...  55.898857   50.000000
# 15  //avatars.mds.yandex.net/get-realty/2039052/ad...  55.881207   59.900002
# 16  //avatars.mds.yandex.net/get-realty/1894107/ad...  55.621304   68.000000
# 17  //avatars.mds.yandex.net/get-realty/2784061/ad...  55.692097   77.000000
# 18  //avatars.mds.yandex.net/get-realty/2784061/ad...  55.688492   65.000000
# 19  //avatars.mds.yandex.net/get-realty/2753842/ad...  55.148903   34.500000
# 20  //avatars.mds.yandex.net/get-realty/1977245/ad...  55.783775   87.000000
# 21  //avatars.mds.yandex.net/get-realty/2807710/ad...  55.886734   43.000000
# 22  //avatars.mds.yandex.net/get-realty/2031790/ad...  55.603874   33.000000
# 23  //avatars.mds.yandex.net/get-realty/2403545/ad...  55.714821   70.000000
# 24  //avatars.mds.yandex.net/get-realty/2006831/ad...  55.598793   51.299999
# 25  //avatars.mds.yandex.net/get-realty/1581062/ad...  55.698536   42.000000
# 26  //avatars.mds.yandex.net/get-realty/2752469/ad...  55.789394   33.000000
# 27  //avatars.mds.yandex.net/get-realty/2779015/ad...  55.842773   64.199997
# 28  //avatars.mds.yandex.net/get-realty/2071710/ad...  55.699425   60.000000
# 29  //avatars.mds.yandex.net/get-realty/1974902/ad...  55.771477   45.000000
#
#     ceiling_height  rooms  ...  public  longitude   price  flats_count  \
# 0             2.64      1  ...    True  37.602478   40000           80
# 1             2.48      1  ...    True  37.743679   25000          222
# 2             0.00      0  ...    True  37.862965   19000          179
# 3             0.00      1  ...    True  37.544224   20000            0
# 4             2.80      3  ...   False  37.411098   68000            0
# 5             0.00      1  ...    True  37.564484   40000          112
# 6             3.00      0  ...   False  37.373302   45000            0
# 7             3.20      1  ...   False  37.706863   40000          115
# 8             2.70      2  ...    True  37.657494  110000           68
# 9             2.74      2  ...    True  37.647129   40000          235
# 10            3.00      0  ...    True  37.709599   30000            0
# 11            3.10      3  ...    True  37.384811   65000           94
# 12            2.64      1  ...    True  37.488331   35000            0
# 13            0.00      1  ...    True  38.443108   14000           70
# 14            3.00      1  ...    True  37.395267   38000           96
# 15            2.64      3  ...    True  37.654171   29900          215
# 16            2.48      2  ...    True  37.493809   55000          249
# 17            0.00      3  ...   False  37.910927   40000            0
# 18            2.50      3  ...   False  37.297626   37990          166
# 19            2.60      1  ...   False  37.470821   17000            0
# 20            0.00      3  ...    True  37.632374   75000            0
# 21            0.00      1  ...    True  37.426960   30000            0
# 22            2.70      0  ...    True  38.083157   22000          372
# 23            0.00      2  ...   False  37.801422   75000          101
# 24            2.48      2  ...    True  37.659466   30000            0
# 25            2.75      1  ...    True  37.935516   27000          192
# 26            3.05      0  ...    True  37.536831   55000            0
# 27            2.64      3  ...    True  37.494194   65000           80
# 28            2.64      3  ...    True  37.756870   46000           80
# 29            0.00      2  ...    True  38.436760   16000           80
#
#     building_type      balcony  locality_name           renovation day_count  \
# 0           PANEL      UNKNOWN         Москва              UNKNOWN       352
# 1           PANEL       LOGGIA         Москва        COSMETIC_DONE       553
# 2         MONOLIT       LOGGIA        Королёв        COSMETIC_DONE       381
# 3           PANEL       LOGGIA       Подольск        COSMETIC_DONE       501
# 4         MONOLIT   TWO_LOGGIA          Химки                 EURO       464
# 5           BRICK      BALCONY         Москва        COSMETIC_DONE       553
# 6         MONOLIT      UNKNOWN         Москва  DESIGNER_RENOVATION      5259
# 7           BRICK       LOGGIA         Москва                 EURO      5259
# 8           PANEL      BALCONY         Москва                 EURO       485
# 9           PANEL      BALCONY         Москва        COSMETIC_DONE      6779
# 10          BLOCK      UNKNOWN         Москва                 EURO       575
# 11        MONOLIT       LOGGIA         Москва  DESIGNER_RENOVATION       298
# 12          BRICK       LOGGIA   Долгопрудный                 EURO       293
# 13          BRICK      BALCONY   Электросталь        COSMETIC_DONE       516
# 14          BRICK      BALCONY         Москва                 EURO       513
# 15          PANEL       LOGGIA         Москва        COSMETIC_DONE       163
# 16          PANEL       LOGGIA         Москва                 EURO       621
# 17          PANEL      UNKNOWN        Люберцы              UNKNOWN       411
# 18          PANEL   TWO_LOGGIA       Одинцово        COSMETIC_DONE       569
# 19          PANEL       LOGGIA          Чехов        COSMETIC_DONE      5259
# 20        UNKNOWN      BALCONY         Москва  DESIGNER_RENOVATION       516
# 21          PANEL       LOGGIA          Химки                 EURO       504
# 22        MONOLIT       LOGGIA      Жуковский                 EURO       451
# 23          BRICK       LOGGIA         Москва  DESIGNER_RENOVATION      5259
# 24          BLOCK      UNKNOWN         Москва        COSMETIC_DONE       353
# 25          PANEL       LOGGIA         Москва        COSMETIC_DONE       642
# 26        UNKNOWN      UNKNOWN         Москва                 EURO       558
# 27          BLOCK  TWO_BALCONY         Москва                 EURO       598
# 28          PANEL      BALCONY         Москва                 EURO       543
# 29          BRICK      BALCONY   Электросталь        COSMETIC_DONE      1626
#
#     day_mean
# 0   2.931129
# 1   2.931129
# 2   2.931129
# 3   2.931129
# 4   2.931129
# 5   2.931129
# 6   2.931129
# 7   2.931129
# 8   2.931129
# 9   1.392246
# 10  2.931129
# 11  2.931129
# 12  2.931129
# 13  2.931129
# 14  2.931129
# 15  2.931129
# 16  2.931129
# 17  2.931129
# 18  2.931129
# 19  2.931129
# 20  2.931129
# 21  2.931129
# 22  2.931129
# 23  2.931129
# 24  2.931129
# 25  2.931129
# 26  2.931129
# 27  2.931129
# 28  2.931129
# 29  2.931129
#
# [30 rows x 32 columns]

# %%
test_data = data_preproccesing(test_data)
test_data.head()
# Out:
# <ipython-input-2-5ba4da441bec>:40: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   data['week'] = data['day'].dt.week
#                       building_series_id  parking  build_year  \
# id
# 13762887891614807236              663294  UNKNOWN        1971
# 14654451946329972059              712125  UNKNOWN        1986
# 17449292585625593873                   0  UNKNOWN        2014
# 15597282206699587329                   0  UNKNOWN        2001
# 3718201047023531068              1564812  UNKNOWN        2019
#
#                       expect_demolition   latitude  total_area  \
# id
# 13762887891614807236                  0  55.795704   36.000000
# 14654451946329972059                  0  55.605583   40.000000
# 17449292585625593873                  0  55.925560   25.000000
# 15597282206699587329                  0  55.432522   42.000000
# 3718201047023531068                   0  55.917530   73.300003
#
#                       ceiling_height  rooms  floors_total  living_area  ...  \
# id                                                                      ...
# 13762887891614807236            2.64      1            12    19.000000  ...
# 14654451946329972059            2.48      1            16    20.000000  ...
# 17449292585625593873            2.70      0            16    12.000000  ...
# 15597282206699587329            2.70      1            10    20.000000  ...
# 3718201047023531068             2.80      3            16    45.799999  ...
#
#                       locality_name_derevnja Kabanovo  \
# id
# 13762887891614807236                                0
# 14654451946329972059                                0
# 17449292585625593873                                0
# 15597282206699587329                                0
# 3718201047023531068                                 0
#
#                       locality_name_derevnja Ivojlovo  \
# id
# 13762887891614807236                                0
# 14654451946329972059                                0
# 17449292585625593873                                0
# 15597282206699587329                                0
# 3718201047023531068                                 0
#
#                       locality_name_selo Vozdvizhenskoe  \
# id
# 13762887891614807236                                  0
# 14654451946329972059                                  0
# 17449292585625593873                                  0
# 15597282206699587329                                  0
# 3718201047023531068                                   0
#
#                       locality_name_derevnja Dolgoe Ledovo  \
# id
# 13762887891614807236                                     0
# 14654451946329972059                                     0
# 17449292585625593873                                     0
# 15597282206699587329                                     0
# 3718201047023531068                                      0
#
#                       locality_name_derevnja Martem'janovo  \
# id
# 13762887891614807236                                     0
# 14654451946329972059                                     0
# 17449292585625593873                                     0
# 15597282206699587329                                     0
# 3718201047023531068                                      0
#
#                       locality_name_poselok Veshki  \
# id
# 13762887891614807236                             0
# 14654451946329972059                             0
# 17449292585625593873                             0
# 15597282206699587329                             0
# 3718201047023531068                              0
#
#                       locality_name_poselok Radiotsentr  \
# id
# 13762887891614807236                                  0
# 14654451946329972059                                  0
# 17449292585625593873                                  0
# 15597282206699587329                                  0
# 3718201047023531068                                   0
#
#                       locality_name_derevnja Zhilino  \
# id
# 13762887891614807236                               0
# 14654451946329972059                               0
# 17449292585625593873                               0
# 15597282206699587329                               0
# 3718201047023531068                                0
#
#                       locality_name_poselok Shuvoe  \
# id
# 13762887891614807236                             0
# 14654451946329972059                             0
# 17449292585625593873                             0
# 15597282206699587329                             0
# 3718201047023531068                              0
#
#                      locality_name_derevnja Vorschikovo
# id
# 13762887891614807236                                  0
# 14654451946329972059                                  0
# 17449292585625593873                                  0
# 15597282206699587329                                  0
# 3718201047023531068                                   0
#
# [5 rows x 879 columns]

# %% [markdown]
# Добавление средней цены

# %%
price_data = pd.DataFrame(test_data[["locality_name", "price"]])
price_groups = {"locality_name": {
    "median": price_data.groupby(["locality_name"]).median()["price"]
}}

# %%
for group in price_groups:
    print ("Processing:", group, end=" ")
    for label in price_groups[group]:
        print (label, end=" ")
        test_data["price_" + group + "_" + label] = test_data.apply(calc_price, axis=1,
                                                                      group=group, label=label)
    print ("")
# Out:
# Processing: locality_name median

# %%
test_data = pd.DataFrame(test_data[['total_area', 'ceiling_height', 'rooms', 'living_area',
                                   'price', 'day_mean', 'price_locality_name_median']])

# %%
test_data.to_csv("exposition_test.basic.csv", index=False)

# %% [markdown]
# # Формирование предсказаний

# %%
test_data = pd.read_csv('exposition_test.basic.csv')

# %%
test_data.columns
# Out:
# Index(['total_area', 'ceiling_height', 'rooms', 'living_area', 'price',
#        'day_mean', 'price_locality_name_median'],
#       dtype='object')

# %%
test_data_mm = pd.DataFrame(scaler.transform(test_data))
test_data_mm.head()
# Out:
#           0         1         2         3         4         5         6
# 0 -0.618155 -0.645106 -0.861151 -0.690542 -0.089888  0.005938 -0.168322
# 1 -0.483202 -1.427399 -0.861151 -0.635189 -0.217544  0.005938 -0.276751
# 2 -0.989277 -0.351746 -2.026671 -1.078012 -0.268606  0.005938 -0.199947
# 3 -0.415725 -0.351746 -0.861151 -0.635189 -0.260095  0.005938 -0.174608
# 4  0.640286  0.137186  1.469889  0.792913  0.148401  0.005938  0.277401

# %% [markdown]
# # -----------------------

# %%
clusters = train_data_mm.groupby("label").mean()["target"]
y = pd.DataFrame(kmeans.predict(test_data_mm))
y["pred"] = y[0].apply(lambda x:clusters.iloc[x])

# %%
y_xgboost = pd.DataFrame(xgb_model.predict(test_data_mm))
y_xgboost["pred"] = y_xgboost[0].apply(lambda x:clusters.iloc[x])

# %%
y_catboost = pd.DataFrame(catboost_model.predict(test_data_mm))
y_catboost["pred"] = y_catboost[0].apply(lambda x:clusters.iloc[x])

# %%
y = (y + y_xgboost + y_catboost) / 3

# %%
y[0] = y[0].apply(lambda n: int(n))

# %%
y.head(5)
# Out:
#     0      pred
# 0  89  2.749164
# 1  71  2.610414
# 2  61  2.719611
# 3  89  2.749164
# 4  58  3.084743

# %% [markdown]
# ### Загрузка решения

# %%
submission = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_sample_submission.tsv', sep='\t')
submission['target'] = np.around(y["pred"])
#submission['target'] = 3
#submission['target'] = np.around(test_data["day_mean"])
submission["target"] = submission["target"].apply(lambda x:max(1, min(x,5))).astype(np.uint8)
submission.to_csv('submission_last.tsv', sep='\t', index=False)

# %% [markdown]
# Используя исходные или очищенные данные, сформируйте предсказание класса объявления из множества exposition_test.tsv.gz
#
# Обязательно нужно использовать одну или несколько моделей кластеризации. Дополнительно можно использовать решающие деревья, CatBoost, LightGBM и XGBoost.
#
# Подсказка: для использования day_mean в классификации/кластеризации потребуется его сформировать для тестовых данных. Это можно сделать либо при помощи других моделей (два этапа классификации), либо построив линейную модель прогноза day_mean от count_day.
#
# Данные:
# * https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_train.tsv.gz
# * https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_test.tsv.gz
# * https://video.ittensive.com/machine-learning/hacktherealty/data/metro.utf8.json
# * https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_sample_submisson.tsv
#
# Итоговый файл с кодом (.py или .ipynb) выложите в github с портфолио.

# %% [markdown]
# # ------------------------------

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from transliterate import translit
from tqdm import notebook
from pyod.models.iforest import IForest
from pyod.models.copod import COPOD
from sklearn.neighbors import LocalOutlierFactor

from catboost import Pool, CatBoostClassifier
from xgboost import XGBClassifier

# %%
def data_preproccesing (data):
# add total items per day
    data_day_count = data.groupby("day").count()["build_year"]
    data["day_count"] = data["day"].apply(lambda x:data_day_count.loc[x])
# approximate values (clean-up)
    data.loc[data.build_year == 0, 'build_year'] = np.NaN
    data['build_year'] = data['build_year'].fillna((data.groupby(['building_series_id'])['build_year'].transform('median')))
    data.loc[data['build_year'].isna(), 'build_year'] = data['build_year'].mean()
    data['build_year'] = data['build_year'].astype(np.uint16)
    if 'has_elevator' in data.columns:
# elevator for 6+ floors
        data.loc[(data.has_elevator==0) & (data.floor>5), 'has_elevator'] = 1
# fix living area
    data.loc[data.living_area == 0, 'living_area'] = np.NaN
    data['living_area'] = data['living_area'].fillna((data.groupby(['rooms'])['living_area'].transform('median')))
# fix price
    data.loc[data.price<100, 'price'] *= 1000
    data.loc[data.price<1000, 'price'] *= 60
    if 'floors_total' in data.columns:
# fix celing height
        data.loc[(data.ceiling_height<2) | (data.ceiling_height>5), 'ceiling_height'] = np.NaN
        data['ceiling_height'] = data['ceiling_height'].fillna(data.groupby(['building_series_id'])['ceiling_height'].transform('median'))
        data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data['ceiling_height'].mean()
# enrich data, % floor
        data['floor'] = data['floor'] / data["floors_total"]
# locality, village/region/moscow/metro
    if 'locality_name' in data.columns:
        data['loctype_village'] = (data['locality_name'].str.match(pat = 'городок|деревня|ДНП|поселок|посёлок|село|СНТ|товарищество|хутор')).astype(np.uint8)
        data['loctype_moscow'] = (data.locality_name == 'Москва').astype(np.uint8)
        data['loctype_region'] = ((data.loctype_village == 0) & (data.loctype_moscow == 0)).astype(np.uint8)
    if "site_id" in data.columns:
        data = data.drop(['site_id', 'main_image', 'area', 'building_id', 'unified_address'], axis=1)
    if 'target_string' in data.columns:
        data = data.drop(['target_string'], axis=1)
# processing date
    if 'day' in data.columns:
        data['day'] = pd.to_datetime(data['day'])
        data['year'] = data['day'].dt.year
        data['month'] = data['day'].dt.month
        data['week'] = data['day'].dt.week
        data['dow'] = data['day'].dt.dayofweek
        data['dom'] = data['day'].dt.day
        data['doy'] = data['day'].dt.dayofyear
        data = data.drop(["day"], axis=1)
# adding holydays, 1-7 Jan, 8 Mar, 1 May, 9 May, 12 Jun, 4 Nov
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2017/
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2018/
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2019/
# http://www.consultant.ru/law/ref/calendar/proizvodstvennye/2020/
        data['is_holyday'] = ((data['year'] == 2017 &
                                (((data['dom'] > 0) & (data['dom'] < 8) & data['month'] == 1) | 
                                (((data['dom'] == 23) | data['dom'] == 24)) & (data['month'] == 2)) |
                                ((data['dom'] == 8) & (data['month'] == 3)) |
                                (((data['dom'] == 1) | (data['dom'] == 8) | (data['dom'] == 9)) & data['month'] == 5) |
                                ((data['dom'] == 12) & (data['month'] == 6)) |
                                ((data['dom'] == 6) & (data['month'] == 11))) |
                              ((data['year'] == 2018) &
                                (((data['dom'] > 0) & (data['dom'] < 9) & data['month'] == 1) | 
                                ((data['dom'] == 23) & (data['month'] == 2)) |
                                (((data['dom'] == 8) | (data['dom'] == 9)) & (data['month'] == 3)) |
                                ((data['dom'] == 30) & (data['month'] == 4)) |
                                (((data['dom'] == 1) | (data['dom'] == 2) | (data['dom'] == 9)) & data['month'] == 5) |
                                (((data['dom'] == 11) | (data['dom'] == 12)) & (data['month'] == 6)) |
                                ((data['dom'] == 5) & (data['month'] == 11)) |
                                ((data['dom'] == 31) & (data['month'] == 12)))) |
                              ((data['year'] == 2019) &
                                (((data['dom'] > 0) & (data['dom'] < 9) & data['month'] == 1) | 
                                ((data['dom'] == 8) & (data['month'] == 3)) |
                                (((data['dom'] == 1) | (data['dom'] == 2) | (data['dom'] == 3) | (data['dom'] == 9) | (data['dom'] == 10)) & data['month'] == 5) |
                                ((data['dom'] == 12) & (data['month'] == 6)) |
                                ((data['dom'] == 4) & (data['month'] == 11)))) |
                              ((data['year'] == 2020) &
                                (((data['dom'] > 0) & (data['dom'] < 9) & data['month'] == 1) | 
                                ((data['dom'] == 24) & (data['month'] == 2)) |
                                ((data['dom'] == 9) & (data['month'] == 3)) |
                                (((data['dom'] == 1) | (data['dom'] == 4) | (data['dom'] == 5) | (data['dom'] == 11)) & data['month'] == 5) |
                                ((data['dom'] == 12) & (data['month'] == 6)) |
                                ((data['dom'] == 4) & (data['month'] == 11))))).astype(np.uint8)
# one-hot vectors
    if 'year' in data.columns:
        for label in ['year', 'month', 'week', 'dow', 'doy', 'dom', 'renovation',
                      'balcony', 'building_type', 'parking', 'floors_total', 'locality_name']:
            for l in data[label].unique():
                data[label + "_" + translit(str(l), "ru", reversed=True)] = (data[label] == l).astype(np.uint8)
# boolean -> int
    if 'studio' in data.columns:
        for label in ['studio', 'has_elevator', 'expect_demolition', 'is_apartment']:
            data[label] = data[label].astype(np.uint8)
# index (remove id from columns)
    if 'id' in data.columns:
        data = data.set_index(['id'])
    return data

# %%
def calc_price (data, group="", label=""):
    if data[group] in price_groups[group][label]:
        return data["price"] / price_groups[group][label][data[group]]
    else:
        return 1

# %%
train_data = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/exposition_train.basic.csv.gz')
train_data = train_data.drop(labels=["doy_108"], axis=1)
train_data.head()
# Out:
#    total_area  ceiling_height  rooms  living_area  price  day_mean  \
# 0  105.000000            3.00      3    50.000000  95000  2.456912
# 1   40.000000            3.00      1    19.200001  25000  3.028689
# 2   37.599998            2.64      0    19.000000  26000  3.091993
# 3   80.000000            3.00      3    49.000000  35000  3.101010
# 4  100.000000            3.00      3    49.000000  80000  2.495468
#
#    price_locality_name_median  target
# 0                    2.261905       1
# 1                    1.000000       2
# 2                    0.619048       2
# 3                    1.250000       2
# 4                    1.904762       3

# %% [markdown]
# ### Нормализация данных
# Приведение всех значений к отрезку [0;1], удалим из данных target

# %%
target = train_data["target"]

# %%
scaler = StandardScaler()

# %%
train_data_mm = pd.DataFrame(scaler.fit_transform(train_data[train_data.columns[:-1]]))

# %%
train_data_mm.head()
# Out:
#           0         1         2         3         4         5         6
# 0  1.709793  1.115052  1.469889  1.025395  0.378181 -1.607090  0.278301
# 1 -0.483202  1.115052 -0.861151 -0.679471 -0.217544  0.337784 -0.132179
# 2 -0.564174 -0.645106 -2.026671 -0.690542 -0.209033  0.553112 -0.256098
# 3  0.866333  1.115052  1.469889  0.970042 -0.132440  0.583783 -0.050858
# 4  1.541101  1.115052  1.469889  0.970042  0.250526 -1.475943  0.162128

# %% [markdown]
# # K-means

# %%
kmeans = KMeans(n_clusters=100, random_state=0, max_iter=200, n_init=10).fit(train_data_mm)

# %%
train_data_mm["label"] = kmeans.labels_
train_data_mm["target"] = train_data["target"]

# %% [markdown]
# # Модели классификации

# %% [markdown]
# ### XGBoost = градиентный бустинг деревьев решений
# (Получим кластеры по всем данным)
# Получим модель XGB

# %%
y = train_data_mm["target"]
x = train_data_mm.drop(labels=["label", "target"], axis=1)

# %%
xgb_model = XGBClassifier(max_depth=17, max_features=27,
                          n_estimators=76, min_samples_leaf=20)

# %%
xgb_model.fit(x, y)
# Out:
# E:\anaconda\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:50:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "max_features", "min_samples_leaf" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [16:50:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=17, max_features=27,
#               min_child_weight=1, min_samples_leaf=20, missing=nan,
#               monotone_constraints='()', n_estimators=76, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1, ...)

# %% [markdown]
# # CatBoost

# %%
train_dataset = Pool(data=x, label=y)
catboost_model = CatBoostClassifier(iterations=10, learning_rate=0.57,
                 random_seed=17, depth=6, loss_function="MultiClass",
                 bootstrap_type="MVS", custom_metric="WKappa")

# %%
cb_params = {
    "depth": range(5,8),
    'learning_rate': np.arange(0.56,0.59,0.01),
    'l2_leaf_reg': range(1,5),
}

cb_grid = catboost_model.grid_search(cb_params, cv=5, X=x, y=y, verbose=True)

print (cb_grid["params"])

catboost_model= CatBoostClassifier(iterations=100,
                learning_rate=cb_grid["params"]["learning_rate"],
                depth=cb_grid["params"]["depth"],
                l2_leaf_reg=cb_grid["params"]["l2_leaf_reg"],
                random_seed=17, loss_function="MultiClass",
                bootstrap_type="MVS", custom_metric="WKappa")
# Out:
# 0:	learn: 1.5479336	test: 1.5493856	best: 1.5493856 (0)	total: 269ms	remaining: 2.42s
# 1:	learn: 1.5303152	test: 1.5323604	best: 1.5323604 (1)	total: 353ms	remaining: 1.41s
# 2:	learn: 1.5200658	test: 1.5228151	best: 1.5228151 (2)	total: 444ms	remaining: 1.04s
# 3:	learn: 1.5117907	test: 1.5143011	best: 1.5143011 (3)	total: 548ms	remaining: 822ms
# 4:	learn: 1.5082575	test: 1.5109742	best: 1.5109742 (4)	total: 637ms	remaining: 637ms
# 5:	learn: 1.5060137	test: 1.5090561	best: 1.5090561 (5)	total: 739ms	remaining: 493ms
# 6:	learn: 1.5036498	test: 1.5064971	best: 1.5064971 (6)	total: 831ms	remaining: 356ms
# 7:	learn: 1.5022063	test: 1.5052227	best: 1.5052227 (7)	total: 938ms	remaining: 234ms
# 8:	learn: 1.5010828	test: 1.5042242	best: 1.5042242 (8)	total: 1.03s	remaining: 114ms
# 9:	learn: 1.5001524	test: 1.5034311	best: 1.5034311 (9)	total: 1.13s	remaining: 0us
#
# bestTest = 1.503431094
# bestIteration = 9
#
# 0:	loss: 1.5034311	best: 1.5034311 (0)	total: 1.44s	remaining: 50.2s
# 0:	learn: 1.5473617	test: 1.5488498	best: 1.5488498 (0)	total: 105ms	remaining: 941ms
# 1:	learn: 1.5281871	test: 1.5302549	best: 1.5302549 (1)	total: 193ms	remaining: 774ms
# 2:	learn: 1.5203307	test: 1.5225754	best: 1.5225754 (2)	total: 276ms	remaining: 645ms
# 3:	learn: 1.5123990	test: 1.5140461	best: 1.5140461 (3)	total: 372ms	remaining: 558ms
# 4:	learn: 1.5086717	test: 1.5105098	best: 1.5105098 (4)	total: 452ms	remaining: 452ms
# 5:	learn: 1.5058069	test: 1.5080382	best: 1.5080382 (5)	total: 543ms	remaining: 362ms
# 6:	learn: 1.5040436	test: 1.5066461	best: 1.5066461 (6)	total: 638ms	remaining: 273ms
# 7:	learn: 1.5020756	test: 1.5049840	best: 1.5049840 (7)	total: 728ms	remaining: 182ms
# 8:	learn: 1.5009923	test: 1.5040416	best: 1.5040416 (8)	total: 805ms	remaining: 89.5ms
# 9:	learn: 1.5002080	test: 1.5034444	best: 1.5034444 (9)	total: 899ms	remaining: 0us
#
# bestTest = 1.503444422
# bestIteration = 9
#
# 1:	loss: 1.5034444	best: 1.5034311 (0)	total: 2.39s	remaining: 40.6s
# 0:	learn: 1.5468081	test: 1.5483326	best: 1.5483326 (0)	total: 112ms	remaining: 1.01s
# 1:	learn: 1.5285803	test: 1.5301342	best: 1.5301342 (1)	total: 205ms	remaining: 821ms
# 2:	learn: 1.5178520	test: 1.5199936	best: 1.5199936 (2)	total: 297ms	remaining: 694ms
# 3:	learn: 1.5131798	test: 1.5156223	best: 1.5156223 (3)	total: 389ms	remaining: 584ms
# 4:	learn: 1.5097905	test: 1.5124132	best: 1.5124132 (4)	total: 483ms	remaining: 483ms
# 5:	learn: 1.5061855	test: 1.5086954	best: 1.5086954 (5)	total: 574ms	remaining: 382ms
# 6:	learn: 1.5043858	test: 1.5072000	best: 1.5072000 (6)	total: 685ms	remaining: 294ms
# 7:	learn: 1.5028275	test: 1.5055900	best: 1.5055900 (7)	total: 779ms	remaining: 195ms
# 8:	learn: 1.5009192	test: 1.5040569	best: 1.5040569 (8)	total: 892ms	remaining: 99.1ms
# 9:	learn: 1.4994623	test: 1.5028496	best: 1.5028496 (9)	total: 1.02s	remaining: 0us
#
# bestTest = 1.502849626
# bestIteration = 9
#
# 2:	loss: 1.5028496	best: 1.5028496 (2)	total: 3.48s	remaining: 38.3s
# 0:	learn: 1.5479579	test: 1.5494141	best: 1.5494141 (0)	total: 130ms	remaining: 1.17s
# 1:	learn: 1.5303365	test: 1.5323822	best: 1.5323822 (1)	total: 236ms	remaining: 943ms
# 2:	learn: 1.5201042	test: 1.5228531	best: 1.5228531 (2)	total: 334ms	remaining: 779ms
# 3:	learn: 1.5118400	test: 1.5143323	best: 1.5143323 (3)	total: 450ms	remaining: 675ms
# 4:	learn: 1.5083128	test: 1.5110076	best: 1.5110076 (4)	total: 556ms	remaining: 556ms
# 5:	learn: 1.5058896	test: 1.5083255	best: 1.5083255 (5)	total: 672ms	remaining: 448ms
# 6:	learn: 1.5035695	test: 1.5064744	best: 1.5064744 (6)	total: 791ms	remaining: 339ms
# 7:	learn: 1.5021958	test: 1.5051745	best: 1.5051745 (7)	total: 903ms	remaining: 226ms
# 8:	learn: 1.5011170	test: 1.5042228	best: 1.5042228 (8)	total: 981ms	remaining: 109ms
# 9:	learn: 1.5003026	test: 1.5035568	best: 1.5035568 (9)	total: 1.09s	remaining: 0us
#
# bestTest = 1.503556838
# bestIteration = 9
#
# 3:	loss: 1.5035568	best: 1.5028496 (2)	total: 4.67s	remaining: 37.4s
# 0:	learn: 1.5473852	test: 1.5488776	best: 1.5488776 (0)	total: 110ms	remaining: 986ms
# 1:	learn: 1.5282135	test: 1.5302785	best: 1.5302785 (1)	total: 202ms	remaining: 809ms
# 2:	learn: 1.5203615	test: 1.5226036	best: 1.5226036 (2)	total: 285ms	remaining: 666ms
# 3:	learn: 1.5124292	test: 1.5140720	best: 1.5140720 (3)	total: 392ms	remaining: 589ms
# 4:	learn: 1.5087078	test: 1.5105383	best: 1.5105383 (4)	total: 476ms	remaining: 476ms
# 5:	learn: 1.5054651	test: 1.5077031	best: 1.5077031 (5)	total: 593ms	remaining: 395ms
# 6:	learn: 1.5036987	test: 1.5062952	best: 1.5062952 (6)	total: 707ms	remaining: 303ms
# 7:	learn: 1.5025740	test: 1.5055444	best: 1.5055444 (7)	total: 815ms	remaining: 204ms
# 8:	learn: 1.5015381	test: 1.5046389	best: 1.5046389 (8)	total: 905ms	remaining: 101ms
# 9:	learn: 1.5000312	test: 1.5034545	best: 1.5034545 (9)	total: 1.02s	remaining: 0us
#
# bestTest = 1.503454547
# bestIteration = 9
#
# 4:	loss: 1.5034545	best: 1.5028496 (2)	total: 5.75s	remaining: 35.7s
# 0:	learn: 1.5468308	test: 1.5483597	best: 1.5483597 (0)	total: 117ms	remaining: 1.06s
# 1:	learn: 1.5286070	test: 1.5301612	best: 1.5301612 (1)	total: 210ms	remaining: 842ms
# 2:	learn: 1.5178804	test: 1.5200235	best: 1.5200235 (2)	total: 316ms	remaining: 738ms
# 3:	learn: 1.5132101	test: 1.5156435	best: 1.5156435 (3)	total: 414ms	remaining: 621ms
# 4:	learn: 1.5105271	test: 1.5131115	best: 1.5131115 (4)	total: 519ms	remaining: 519ms
# 5:	learn: 1.5065051	test: 1.5087938	best: 1.5087938 (5)	total: 602ms	remaining: 402ms
# 6:	learn: 1.5049591	test: 1.5075104	best: 1.5075104 (6)	total: 689ms	remaining: 295ms
# 7:	learn: 1.5037808	test: 1.5064567	best: 1.5064567 (7)	total: 760ms	remaining: 190ms
# 8:	learn: 1.5027428	test: 1.5055119	best: 1.5055119 (8)	total: 850ms	remaining: 94.5ms
# 9:	learn: 1.5015590	test: 1.5044642	best: 1.5044642 (9)	total: 938ms	remaining: 0us
#
# bestTest = 1.504464247
# bestIteration = 9
#
# 5:	loss: 1.5044642	best: 1.5028496 (2)	total: 6.74s	remaining: 33.7s
# 0:	learn: 1.5479821	test: 1.5494423	best: 1.5494423 (0)	total: 81.6ms	remaining: 735ms
# 1:	learn: 1.5303567	test: 1.5324043	best: 1.5324043 (1)	total: 178ms	remaining: 711ms
# 2:	learn: 1.5201404	test: 1.5228906	best: 1.5228906 (2)	total: 270ms	remaining: 629ms
# 3:	learn: 1.5118831	test: 1.5143649	best: 1.5143649 (3)	total: 365ms	remaining: 548ms
# 4:	learn: 1.5083603	test: 1.5110425	best: 1.5110425 (4)	total: 445ms	remaining: 445ms
# 5:	learn: 1.5059259	test: 1.5083466	best: 1.5083466 (5)	total: 525ms	remaining: 350ms
# 6:	learn: 1.5036078	test: 1.5064935	best: 1.5064935 (6)	total: 611ms	remaining: 262ms
# 7:	learn: 1.5022347	test: 1.5051912	best: 1.5051912 (7)	total: 694ms	remaining: 174ms
# 8:	learn: 1.5011602	test: 1.5042375	best: 1.5042375 (8)	total: 781ms	remaining: 86.8ms
# 9:	learn: 1.5003484	test: 1.5035705	best: 1.5035705 (9)	total: 866ms	remaining: 0us
#
# bestTest = 1.503570466
# bestIteration = 9
#
# 6:	loss: 1.5035705	best: 1.5028496 (2)	total: 7.64s	remaining: 31.7s
# 0:	learn: 1.5474087	test: 1.5489051	best: 1.5489051 (0)	total: 109ms	remaining: 983ms
# 1:	learn: 1.5282385	test: 1.5303017	best: 1.5303017 (1)	total: 207ms	remaining: 828ms
# 2:	learn: 1.5203911	test: 1.5226315	best: 1.5226315 (2)	total: 296ms	remaining: 691ms
# 3:	learn: 1.5124576	test: 1.5140988	best: 1.5140988 (3)	total: 402ms	remaining: 603ms
# 4:	learn: 1.5087418	test: 1.5105694	best: 1.5105694 (4)	total: 488ms	remaining: 488ms
# 5:	learn: 1.5052722	test: 1.5075329	best: 1.5075329 (5)	total: 592ms	remaining: 394ms
# 6:	learn: 1.5035015	test: 1.5061048	best: 1.5061048 (6)	total: 678ms	remaining: 290ms
# 7:	learn: 1.5022208	test: 1.5049555	best: 1.5049555 (7)	total: 767ms	remaining: 192ms
# 8:	learn: 1.5011003	test: 1.5039897	best: 1.5039897 (8)	total: 844ms	remaining: 93.8ms
# 9:	learn: 1.4999876	test: 1.5032406	best: 1.5032406 (9)	total: 929ms	remaining: 0us
#
# bestTest = 1.503240582
# bestIteration = 9
#
# 7:	loss: 1.5032406	best: 1.5028496 (2)	total: 8.64s	remaining: 30.2s
# 0:	learn: 1.5468536	test: 1.5483865	best: 1.5483865 (0)	total: 106ms	remaining: 955ms
# 1:	learn: 1.5286322	test: 1.5301874	best: 1.5301874 (1)	total: 196ms	remaining: 786ms
# 2:	learn: 1.5179072	test: 1.5200523	best: 1.5200523 (2)	total: 286ms	remaining: 668ms
# 3:	learn: 1.5132376	test: 1.5156666	best: 1.5156666 (3)	total: 370ms	remaining: 555ms
# 4:	learn: 1.5105540	test: 1.5131316	best: 1.5131316 (4)	total: 461ms	remaining: 461ms
# 5:	learn: 1.5075688	test: 1.5099953	best: 1.5099953 (5)	total: 543ms	remaining: 362ms
# 6:	learn: 1.5041969	test: 1.5067166	best: 1.5067166 (6)	total: 631ms	remaining: 271ms
# 7:	learn: 1.5029213	test: 1.5055628	best: 1.5055628 (7)	total: 719ms	remaining: 180ms
# 8:	learn: 1.5021203	test: 1.5049755	best: 1.5049755 (8)	total: 807ms	remaining: 89.6ms
# 9:	learn: 1.5003836	test: 1.5036787	best: 1.5036787 (9)	total: 900ms	remaining: 0us
#
# bestTest = 1.503678656
# bestIteration = 9
#
# 8:	loss: 1.5036787	best: 1.5028496 (2)	total: 9.6s	remaining: 28.8s
# 0:	learn: 1.5480062	test: 1.5494703	best: 1.5494703 (0)	total: 132ms	remaining: 1.19s
# 1:	learn: 1.5303764	test: 1.5324261	best: 1.5324261 (1)	total: 227ms	remaining: 907ms
# 2:	learn: 1.5201755	test: 1.5229273	best: 1.5229273 (2)	total: 308ms	remaining: 718ms
# 3:	learn: 1.5119227	test: 1.5143977	best: 1.5143977 (3)	total: 388ms	remaining: 582ms
# 4:	learn: 1.5084036	test: 1.5110776	best: 1.5110776 (4)	total: 470ms	remaining: 470ms
# 5:	learn: 1.5059585	test: 1.5083687	best: 1.5083687 (5)	total: 560ms	remaining: 374ms
# 6:	learn: 1.5036419	test: 1.5065138	best: 1.5065138 (6)	total: 641ms	remaining: 275ms
# 7:	learn: 1.5022689	test: 1.5052094	best: 1.5052094 (7)	total: 718ms	remaining: 180ms
# 8:	learn: 1.5011970	test: 1.5042540	best: 1.5042540 (8)	total: 797ms	remaining: 88.5ms
# 9:	learn: 1.5003873	test: 1.5035861	best: 1.5035861 (9)	total: 889ms	remaining: 0us
#
# bestTest = 1.503586128
# bestIteration = 9
#
# 9:	loss: 1.5035861	best: 1.5028496 (2)	total: 10.5s	remaining: 27.4s
# 0:	learn: 1.5474322	test: 1.5489324	best: 1.5489324 (0)	total: 92.5ms	remaining: 832ms
# 1:	learn: 1.5282627	test: 1.5303244	best: 1.5303244 (1)	total: 187ms	remaining: 748ms
# 2:	learn: 1.5204197	test: 1.5226589	best: 1.5226589 (2)	total: 270ms	remaining: 630ms
# 3:	learn: 1.5124851	test: 1.5141256	best: 1.5141256 (3)	total: 364ms	remaining: 545ms
# 4:	learn: 1.5087747	test: 1.5106011	best: 1.5106011 (4)	total: 449ms	remaining: 449ms
# 5:	learn: 1.5050566	test: 1.5071406	best: 1.5071406 (5)	total: 541ms	remaining: 361ms
# 6:	learn: 1.5038376	test: 1.5060608	best: 1.5060608 (6)	total: 627ms	remaining: 269ms
# 7:	learn: 1.5023820	test: 1.5047879	best: 1.5047879 (7)	total: 725ms	remaining: 181ms
# 8:	learn: 1.5008205	test: 1.5036679	best: 1.5036679 (8)	total: 824ms	remaining: 91.6ms
# 9:	learn: 1.4999945	test: 1.5030168	best: 1.5030168 (9)	total: 923ms	remaining: 0us
#
# bestTest = 1.503016806
# bestIteration = 9
#
# 10:	loss: 1.5030168	best: 1.5028496 (2)	total: 11.5s	remaining: 26.2s
# 0:	learn: 1.5468765	test: 1.5484131	best: 1.5484131 (0)	total: 103ms	remaining: 926ms
# 1:	learn: 1.5286564	test: 1.5302128	best: 1.5302128 (1)	total: 206ms	remaining: 824ms
# 2:	learn: 1.5179330	test: 1.5200802	best: 1.5200802 (2)	total: 300ms	remaining: 700ms
# 3:	learn: 1.5132635	test: 1.5156902	best: 1.5156902 (3)	total: 394ms	remaining: 591ms
# 4:	learn: 1.5105790	test: 1.5131529	best: 1.5131529 (4)	total: 475ms	remaining: 475ms
# 5:	learn: 1.5076032	test: 1.5100305	best: 1.5100305 (5)	total: 572ms	remaining: 381ms
# 6:	learn: 1.5042323	test: 1.5067489	best: 1.5067489 (6)	total: 668ms	remaining: 286ms
# 7:	learn: 1.5029515	test: 1.5055877	best: 1.5055877 (7)	total: 750ms	remaining: 188ms
# 8:	learn: 1.5021542	test: 1.5050018	best: 1.5050018 (8)	total: 843ms	remaining: 93.6ms
# 9:	learn: 1.5004182	test: 1.5037051	best: 1.5037051 (9)	total: 946ms	remaining: 0us
#
# bestTest = 1.503705104
# bestIteration = 9
#
# 11:	loss: 1.5037051	best: 1.5028496 (2)	total: 12.5s	remaining: 25.1s
# 0:	learn: 1.5464104	test: 1.5480424	best: 1.5480424 (0)	total: 122ms	remaining: 1.1s
# 1:	learn: 1.5270578	test: 1.5297645	best: 1.5297645 (1)	total: 239ms	remaining: 956ms
# 2:	learn: 1.5139495	test: 1.5169256	best: 1.5169256 (2)	total: 353ms	remaining: 824ms
# 3:	learn: 1.5089334	test: 1.5122272	best: 1.5122272 (3)	total: 456ms	remaining: 684ms
# 4:	learn: 1.5062879	test: 1.5096619	best: 1.5096619 (4)	total: 559ms	remaining: 559ms
# 5:	learn: 1.5027019	test: 1.5060933	best: 1.5060933 (5)	total: 674ms	remaining: 449ms
# 6:	learn: 1.5014515	test: 1.5049386	best: 1.5049386 (6)	total: 775ms	remaining: 332ms
# 7:	learn: 1.4996800	test: 1.5032224	best: 1.5032224 (7)	total: 880ms	remaining: 220ms
# 8:	learn: 1.4988760	test: 1.5026140	best: 1.5026140 (8)	total: 984ms	remaining: 109ms
# 9:	learn: 1.4974879	test: 1.5013335	best: 1.5013335 (9)	total: 1.1s	remaining: 0us
#
# bestTest = 1.501333451
# bestIteration = 9
#
# 12:	loss: 1.5013335	best: 1.5013335 (12)	total: 13.7s	remaining: 24.3s
# 0:	learn: 1.5458249	test: 1.5474963	best: 1.5474963 (0)	total: 101ms	remaining: 911ms
# 1:	learn: 1.5266635	test: 1.5294196	best: 1.5294196 (1)	total: 205ms	remaining: 820ms
# 2:	learn: 1.5136469	test: 1.5166773	best: 1.5166773 (2)	total: 304ms	remaining: 710ms
# 3:	learn: 1.5087163	test: 1.5120640	best: 1.5120640 (3)	total: 397ms	remaining: 596ms
# 4:	learn: 1.5061316	test: 1.5095500	best: 1.5095500 (4)	total: 486ms	remaining: 486ms
# 5:	learn: 1.5025998	test: 1.5060338	best: 1.5060338 (5)	total: 591ms	remaining: 394ms
# 6:	learn: 1.5013660	test: 1.5048953	best: 1.5048953 (6)	total: 690ms	remaining: 296ms
# 7:	learn: 1.4996019	test: 1.5031890	best: 1.5031890 (7)	total: 782ms	remaining: 195ms
# 8:	learn: 1.4987904	test: 1.5025707	best: 1.5025707 (8)	total: 884ms	remaining: 98.2ms
# 9:	learn: 1.4973976	test: 1.5012866	best: 1.5012866 (9)	total: 999ms	remaining: 0us
#
# bestTest = 1.501286567
# bestIteration = 9
#
# 13:	loss: 1.5012866	best: 1.5012866 (13)	total: 14.8s	remaining: 23.2s
# 0:	learn: 1.5452581	test: 1.5469694	best: 1.5469694 (0)	total: 122ms	remaining: 1.09s
# 1:	learn: 1.5262926	test: 1.5290982	best: 1.5290982 (1)	total: 234ms	remaining: 937ms
# 2:	learn: 1.5145935	test: 1.5176288	best: 1.5176288 (2)	total: 344ms	remaining: 804ms
# 3:	learn: 1.5088489	test: 1.5119207	best: 1.5119207 (3)	total: 457ms	remaining: 685ms
# 4:	learn: 1.5063160	test: 1.5094429	best: 1.5094429 (4)	total: 556ms	remaining: 556ms
# 5:	learn: 1.5023751	test: 1.5055908	best: 1.5055908 (5)	total: 673ms	remaining: 448ms
# 6:	learn: 1.5010692	test: 1.5043849	best: 1.5043849 (6)	total: 779ms	remaining: 334ms
# 7:	learn: 1.4995890	test: 1.5031270	best: 1.5031270 (7)	total: 886ms	remaining: 221ms
# 8:	learn: 1.4979883	test: 1.5017284	best: 1.5017284 (8)	total: 988ms	remaining: 110ms
# 9:	learn: 1.4966044	test: 1.5004328	best: 1.5004328 (9)	total: 1.09s	remaining: 0us
#
# bestTest = 1.500432792
# bestIteration = 9
#
# 14:	loss: 1.5004328	best: 1.5004328 (14)	total: 16s	remaining: 22.3s
# 0:	learn: 1.5464577	test: 1.5480917	best: 1.5480917 (0)	total: 136ms	remaining: 1.23s
# 1:	learn: 1.5271181	test: 1.5298057	best: 1.5298057 (1)	total: 230ms	remaining: 920ms
# 2:	learn: 1.5140241	test: 1.5169824	best: 1.5169824 (2)	total: 318ms	remaining: 742ms
# 3:	learn: 1.5090202	test: 1.5122950	best: 1.5122950 (3)	total: 419ms	remaining: 629ms
# 4:	learn: 1.5063697	test: 1.5097193	best: 1.5097193 (4)	total: 509ms	remaining: 509ms
# 5:	learn: 1.5027897	test: 1.5061444	best: 1.5061444 (5)	total: 611ms	remaining: 407ms
# 6:	learn: 1.5015023	test: 1.5049268	best: 1.5049268 (6)	total: 704ms	remaining: 302ms
# 7:	learn: 1.4997385	test: 1.5032173	best: 1.5032173 (7)	total: 807ms	remaining: 202ms
# 8:	learn: 1.4989367	test: 1.5026102	best: 1.5026102 (8)	total: 898ms	remaining: 99.7ms
# 9:	learn: 1.4975532	test: 1.5013316	best: 1.5013316 (9)	total: 995ms	remaining: 0us
#
# bestTest = 1.501331629
# bestIteration = 9
#
# 15:	loss: 1.5013316	best: 1.5004328 (14)	total: 17s	remaining: 21.3s
# 0:	learn: 1.5458711	test: 1.5475446	best: 1.5475446 (0)	total: 120ms	remaining: 1.08s
# 1:	learn: 1.5267226	test: 1.5294594	best: 1.5294594 (1)	total: 216ms	remaining: 863ms
# 2:	learn: 1.5137201	test: 1.5167324	best: 1.5167324 (2)	total: 310ms	remaining: 724ms
# 3:	learn: 1.5088018	test: 1.5121303	best: 1.5121303 (3)	total: 406ms	remaining: 609ms
# 4:	learn: 1.5062125	test: 1.5096061	best: 1.5096061 (4)	total: 505ms	remaining: 505ms
# 5:	learn: 1.5026866	test: 1.5060833	best: 1.5060833 (5)	total: 612ms	remaining: 408ms
# 6:	learn: 1.5014169	test: 1.5048820	best: 1.5048820 (6)	total: 701ms	remaining: 300ms
# 7:	learn: 1.4996592	test: 1.5031809	best: 1.5031809 (7)	total: 798ms	remaining: 199ms
# 8:	learn: 1.4988499	test: 1.5025639	best: 1.5025639 (8)	total: 889ms	remaining: 98.8ms
# 9:	learn: 1.4974617	test: 1.5012816	best: 1.5012816 (9)	total: 984ms	remaining: 0us
#
# bestTest = 1.501281563
# bestIteration = 9
#
# 16:	loss: 1.5012816	best: 1.5004328 (14)	total: 18s	remaining: 20.2s
# 0:	learn: 1.5453033	test: 1.5470166	best: 1.5470166 (0)	total: 125ms	remaining: 1.13s
# 1:	learn: 1.5263505	test: 1.5291364	best: 1.5291364 (1)	total: 219ms	remaining: 876ms
# 2:	learn: 1.5146543	test: 1.5176675	best: 1.5176675 (2)	total: 302ms	remaining: 704ms
# 3:	learn: 1.5089295	test: 1.5119818	best: 1.5119818 (3)	total: 397ms	remaining: 596ms
# 4:	learn: 1.5063949	test: 1.5094963	best: 1.5094963 (4)	total: 480ms	remaining: 480ms
# 5:	learn: 1.5024580	test: 1.5056409	best: 1.5056409 (5)	total: 588ms	remaining: 392ms
# 6:	learn: 1.5011534	test: 1.5044302	best: 1.5044302 (6)	total: 705ms	remaining: 302ms
# 7:	learn: 1.4996704	test: 1.5031585	best: 1.5031585 (7)	total: 801ms	remaining: 200ms
# 8:	learn: 1.4980895	test: 1.5017799	best: 1.5017799 (8)	total: 904ms	remaining: 100ms
# 9:	learn: 1.4967155	test: 1.5004839	best: 1.5004839 (9)	total: 999ms	remaining: 0us
#
# bestTest = 1.500483896
# bestIteration = 9
#
# 17:	loss: 1.5004839	best: 1.5004328 (14)	total: 19.1s	remaining: 19.1s
# 0:	learn: 1.5465033	test: 1.5481405	best: 1.5481405 (0)	total: 147ms	remaining: 1.32s
# 1:	learn: 1.5271735	test: 1.5298485	best: 1.5298485 (1)	total: 258ms	remaining: 1.03s
# 2:	learn: 1.5140927	test: 1.5170400	best: 1.5170400 (2)	total: 362ms	remaining: 845ms
# 3:	learn: 1.5090987	test: 1.5123631	best: 1.5123631 (3)	total: 459ms	remaining: 689ms
# 4:	learn: 1.5064411	test: 1.5097776	best: 1.5097776 (4)	total: 542ms	remaining: 542ms
# 5:	learn: 1.5028650	test: 1.5061995	best: 1.5061995 (5)	total: 643ms	remaining: 429ms
# 6:	learn: 1.5015758	test: 1.5049755	best: 1.5049755 (6)	total: 740ms	remaining: 317ms
# 7:	learn: 1.4998132	test: 1.5032599	best: 1.5032599 (7)	total: 836ms	remaining: 209ms
# 8:	learn: 1.4990125	test: 1.5026535	best: 1.5026535 (8)	total: 938ms	remaining: 104ms
# 9:	learn: 1.4976347	test: 1.5013776	best: 1.5013776 (9)	total: 1.02s	remaining: 0us
#
# bestTest = 1.501377634
# bestIteration = 9
#
# 18:	loss: 1.5013776	best: 1.5004328 (14)	total: 20.2s	remaining: 18.1s
# 0:	learn: 1.5459158	test: 1.5475925	best: 1.5475925 (0)	total: 96.4ms	remaining: 868ms
# 1:	learn: 1.5267770	test: 1.5295009	best: 1.5295009 (1)	total: 199ms	remaining: 796ms
# 2:	learn: 1.5137875	test: 1.5167886	best: 1.5167886 (2)	total: 308ms	remaining: 718ms
# 3:	learn: 1.5088794	test: 1.5121971	best: 1.5121971 (3)	total: 400ms	remaining: 600ms
# 4:	learn: 1.5062831	test: 1.5096634	best: 1.5096634 (4)	total: 504ms	remaining: 504ms
# 5:	learn: 1.5027611	test: 1.5061373	best: 1.5061373 (5)	total: 618ms	remaining: 412ms
# 6:	learn: 1.5014896	test: 1.5049294	best: 1.5049294 (6)	total: 717ms	remaining: 307ms
# 7:	learn: 1.4997328	test: 1.5032217	best: 1.5032217 (7)	total: 818ms	remaining: 205ms
# 8:	learn: 1.4989246	test: 1.5026054	best: 1.5026054 (8)	total: 928ms	remaining: 103ms
# 9:	learn: 1.4975420	test: 1.5013256	best: 1.5013256 (9)	total: 1.02s	remaining: 0us
#
# bestTest = 1.501325606
# bestIteration = 9
#
# 19:	loss: 1.5013256	best: 1.5004328 (14)	total: 21.2s	remaining: 17s
# 0:	learn: 1.5453471	test: 1.5470636	best: 1.5470636 (0)	total: 109ms	remaining: 978ms
# 1:	learn: 1.5264038	test: 1.5291767	best: 1.5291767 (1)	total: 223ms	remaining: 892ms
# 2:	learn: 1.5147109	test: 1.5177091	best: 1.5177091 (2)	total: 333ms	remaining: 777ms
# 3:	learn: 1.5090027	test: 1.5120436	best: 1.5120436 (3)	total: 440ms	remaining: 660ms
# 4:	learn: 1.5064633	test: 1.5095506	best: 1.5095506 (4)	total: 534ms	remaining: 534ms
# 5:	learn: 1.5023670	test: 1.5054864	best: 1.5054864 (5)	total: 640ms	remaining: 427ms
# 6:	learn: 1.5011031	test: 1.5043133	best: 1.5043133 (6)	total: 740ms	remaining: 317ms
# 7:	learn: 1.4997471	test: 1.5031026	best: 1.5031026 (7)	total: 836ms	remaining: 209ms
# 8:	learn: 1.4983245	test: 1.5019141	best: 1.5019141 (8)	total: 946ms	remaining: 105ms
# 9:	learn: 1.4971082	test: 1.5008280	best: 1.5008280 (9)	total: 1.04s	remaining: 0us
#
# bestTest = 1.500828035
# bestIteration = 9
#
# 20:	loss: 1.5008280	best: 1.5004328 (14)	total: 22.4s	remaining: 16s
# 0:	learn: 1.5465473	test: 1.5481880	best: 1.5481880 (0)	total: 107ms	remaining: 959ms
# 1:	learn: 1.5272249	test: 1.5298910	best: 1.5298910 (1)	total: 215ms	remaining: 862ms
# 2:	learn: 1.5141567	test: 1.5170966	best: 1.5170966 (2)	total: 315ms	remaining: 735ms
# 3:	learn: 1.5091715	test: 1.5124296	best: 1.5124296 (3)	total: 419ms	remaining: 628ms
# 4:	learn: 1.5065057	test: 1.5098346	best: 1.5098346 (4)	total: 511ms	remaining: 511ms
# 5:	learn: 1.5029326	test: 1.5062543	best: 1.5062543 (5)	total: 621ms	remaining: 414ms
# 6:	learn: 1.5016414	test: 1.5050245	best: 1.5050245 (6)	total: 721ms	remaining: 309ms
# 7:	learn: 1.4998803	test: 1.5033049	best: 1.5033049 (7)	total: 810ms	remaining: 203ms
# 8:	learn: 1.4990806	test: 1.5026995	best: 1.5026995 (8)	total: 903ms	remaining: 100ms
# 9:	learn: 1.4977079	test: 1.5014267	best: 1.5014267 (9)	total: 1s	remaining: 0us
#
# bestTest = 1.501426703
# bestIteration = 9
#
# 21:	loss: 1.5014267	best: 1.5004328 (14)	total: 23.4s	remaining: 14.9s
# 0:	learn: 1.5459590	test: 1.5476393	best: 1.5476393 (0)	total: 103ms	remaining: 925ms
# 1:	learn: 1.5268275	test: 1.5295424	best: 1.5295424 (1)	total: 210ms	remaining: 841ms
# 2:	learn: 1.5138504	test: 1.5168439	best: 1.5168439 (2)	total: 310ms	remaining: 724ms
# 3:	learn: 1.5089512	test: 1.5122626	best: 1.5122626 (3)	total: 415ms	remaining: 623ms
# 4:	learn: 1.5063469	test: 1.5097195	best: 1.5097195 (4)	total: 516ms	remaining: 516ms
# 5:	learn: 1.5028279	test: 1.5061912	best: 1.5061912 (5)	total: 631ms	remaining: 420ms
# 6:	learn: 1.5015544	test: 1.5049773	best: 1.5049773 (6)	total: 726ms	remaining: 311ms
# 7:	learn: 1.4997988	test: 1.5032652	best: 1.5032652 (7)	total: 820ms	remaining: 205ms
# 8:	learn: 1.4989917	test: 1.5026498	best: 1.5026498 (8)	total: 915ms	remaining: 102ms
# 9:	learn: 1.4976141	test: 1.5013730	best: 1.5013730 (9)	total: 1.02s	remaining: 0us
#
# bestTest = 1.501373047
# bestIteration = 9
#
# 22:	loss: 1.5013730	best: 1.5004328 (14)	total: 24.5s	remaining: 13.8s
# 0:	learn: 1.5453894	test: 1.5471095	best: 1.5471095 (0)	total: 112ms	remaining: 1.01s
# 1:	learn: 1.5264534	test: 1.5292171	best: 1.5292171 (1)	total: 225ms	remaining: 901ms
# 2:	learn: 1.5147641	test: 1.5177515	best: 1.5177515 (2)	total: 326ms	remaining: 762ms
# 3:	learn: 1.5090704	test: 1.5121042	best: 1.5121042 (3)	total: 437ms	remaining: 655ms
# 4:	learn: 1.5065249	test: 1.5096036	best: 1.5096036 (4)	total: 525ms	remaining: 525ms
# 5:	learn: 1.5024312	test: 1.5055369	best: 1.5055369 (5)	total: 642ms	remaining: 428ms
# 6:	learn: 1.5012185	test: 1.5044267	best: 1.5044267 (6)	total: 750ms	remaining: 321ms
# 7:	learn: 1.4998533	test: 1.5031995	best: 1.5031995 (7)	total: 846ms	remaining: 211ms
# 8:	learn: 1.4984331	test: 1.5020120	best: 1.5020120 (8)	total: 949ms	remaining: 105ms
# 9:	learn: 1.4972248	test: 1.5009275	best: 1.5009275 (9)	total: 1.05s	remaining: 0us
#
# bestTest = 1.500927518
# bestIteration = 9
#
# 23:	loss: 1.5009275	best: 1.5004328 (14)	total: 25.6s	remaining: 12.8s
# 0:	learn: 1.5443359	test: 1.5461182	best: 1.5461182 (0)	total: 136ms	remaining: 1.22s
# 1:	learn: 1.5203129	test: 1.5224825	best: 1.5224825 (1)	total: 264ms	remaining: 1.05s
# 2:	learn: 1.5098632	test: 1.5121229	best: 1.5121229 (2)	total: 387ms	remaining: 903ms
# 3:	learn: 1.5048892	test: 1.5077901	best: 1.5077901 (3)	total: 516ms	remaining: 774ms
# 4:	learn: 1.5024392	test: 1.5053842	best: 1.5053842 (4)	total: 642ms	remaining: 642ms
# 5:	learn: 1.4995389	test: 1.5029534	best: 1.5029534 (5)	total: 782ms	remaining: 522ms
# 6:	learn: 1.4970206	test: 1.5009210	best: 1.5009210 (6)	total: 910ms	remaining: 390ms
# 7:	learn: 1.4954347	test: 1.4998321	best: 1.4998321 (7)	total: 1.07s	remaining: 267ms
# 8:	learn: 1.4942620	test: 1.4991305	best: 1.4991305 (8)	total: 1.22s	remaining: 136ms
# 9:	learn: 1.4929185	test: 1.4983535	best: 1.4983535 (9)	total: 1.36s	remaining: 0us
#
# bestTest = 1.498353502
# bestIteration = 9
#
# 24:	loss: 1.4983535	best: 1.4983535 (24)	total: 27s	remaining: 11.9s
# 0:	learn: 1.5437435	test: 1.5455686	best: 1.5455686 (0)	total: 132ms	remaining: 1.18s
# 1:	learn: 1.5198447	test: 1.5221939	best: 1.5221939 (1)	total: 286ms	remaining: 1.14s
# 2:	learn: 1.5092489	test: 1.5124335	best: 1.5124335 (2)	total: 457ms	remaining: 1.06s
# 3:	learn: 1.5048934	test: 1.5082447	best: 1.5082447 (3)	total: 614ms	remaining: 921ms
# 4:	learn: 1.5019311	test: 1.5055733	best: 1.5055733 (4)	total: 765ms	remaining: 765ms
# 5:	learn: 1.4987791	test: 1.5026623	best: 1.5026623 (5)	total: 932ms	remaining: 621ms
# 6:	learn: 1.4963708	test: 1.5007273	best: 1.5007273 (6)	total: 1.09s	remaining: 469ms
# 7:	learn: 1.4951297	test: 1.5001050	best: 1.5001050 (7)	total: 1.25s	remaining: 312ms
# 8:	learn: 1.4939022	test: 1.4991684	best: 1.4991684 (8)	total: 1.41s	remaining: 156ms
# 9:	learn: 1.4922887	test: 1.4980184	best: 1.4980184 (9)	total: 1.56s	remaining: 0us
#
# bestTest = 1.498018363
# bestIteration = 9
#
# 25:	loss: 1.4980184	best: 1.4980184 (25)	total: 28.6s	remaining: 11s
# 0:	learn: 1.5431710	test: 1.5450393	best: 1.5450393 (0)	total: 155ms	remaining: 1.4s
# 1:	learn: 1.5193939	test: 1.5217871	best: 1.5217871 (1)	total: 314ms	remaining: 1.25s
# 2:	learn: 1.5089421	test: 1.5121832	best: 1.5121832 (2)	total: 479ms	remaining: 1.12s
# 3:	learn: 1.5046490	test: 1.5080540	best: 1.5080540 (3)	total: 613ms	remaining: 919ms
# 4:	learn: 1.5017563	test: 1.5054509	best: 1.5054509 (4)	total: 740ms	remaining: 740ms
# 5:	learn: 1.4998116	test: 1.5037623	best: 1.5037623 (5)	total: 892ms	remaining: 595ms
# 6:	learn: 1.4973616	test: 1.5014061	best: 1.5014061 (6)	total: 1.06s	remaining: 455ms
# 7:	learn: 1.4958204	test: 1.5005343	best: 1.5005343 (7)	total: 1.23s	remaining: 306ms
# 8:	learn: 1.4941649	test: 1.4991625	best: 1.4991625 (8)	total: 1.4s	remaining: 155ms
# 9:	learn: 1.4923961	test: 1.4981075	best: 1.4981075 (9)	total: 1.59s	remaining: 0us
#
# bestTest = 1.4981075
# bestIteration = 9
#
# 26:	loss: 1.4981075	best: 1.4980184 (25)	total: 30.3s	remaining: 10.1s
# 0:	learn: 1.5443976	test: 1.5461763	best: 1.5461763 (0)	total: 156ms	remaining: 1.4s
# 1:	learn: 1.5203859	test: 1.5225415	best: 1.5225415 (1)	total: 311ms	remaining: 1.24s
# 2:	learn: 1.5099297	test: 1.5121796	best: 1.5121796 (2)	total: 459ms	remaining: 1.07s
# 3:	learn: 1.5049589	test: 1.5078436	best: 1.5078436 (3)	total: 618ms	remaining: 926ms
# 4:	learn: 1.5025113	test: 1.5054444	best: 1.5054444 (4)	total: 756ms	remaining: 756ms
# 5:	learn: 1.4996417	test: 1.5030085	best: 1.5030085 (5)	total: 894ms	remaining: 596ms
# 6:	learn: 1.4971271	test: 1.5009706	best: 1.5009706 (6)	total: 1.05s	remaining: 449ms
# 7:	learn: 1.4955814	test: 1.4998774	best: 1.4998774 (7)	total: 1.18s	remaining: 296ms
# 8:	learn: 1.4944189	test: 1.4991686	best: 1.4991686 (8)	total: 1.32s	remaining: 147ms
# 9:	learn: 1.4930911	test: 1.4983815	best: 1.4983815 (9)	total: 1.45s	remaining: 0us
#
# bestTest = 1.498381524
# bestIteration = 9
#
# 27:	loss: 1.4983815	best: 1.4980184 (25)	total: 31.8s	remaining: 9.09s
# 0:	learn: 1.5438040	test: 1.5456256	best: 1.5456256 (0)	total: 161ms	remaining: 1.45s
# 1:	learn: 1.5199243	test: 1.5222532	best: 1.5222532 (1)	total: 287ms	remaining: 1.15s
# 2:	learn: 1.5093461	test: 1.5125051	best: 1.5125051 (2)	total: 417ms	remaining: 973ms
# 3:	learn: 1.5050134	test: 1.5083144	best: 1.5083144 (3)	total: 544ms	remaining: 816ms
# 4:	learn: 1.5018891	test: 1.5053858	best: 1.5053858 (4)	total: 696ms	remaining: 696ms
# 5:	learn: 1.5000909	test: 1.5039281	best: 1.5039281 (5)	total: 828ms	remaining: 552ms
# 6:	learn: 1.4974702	test: 1.5018000	best: 1.5018000 (6)	total: 962ms	remaining: 412ms
# 7:	learn: 1.4957265	test: 1.5007116	best: 1.5007116 (7)	total: 1.1s	remaining: 275ms
# 8:	learn: 1.4945106	test: 1.4995840	best: 1.4995840 (8)	total: 1.24s	remaining: 138ms
# 9:	learn: 1.4931050	test: 1.4987744	best: 1.4987744 (9)	total: 1.4s	remaining: 0us
#
# bestTest = 1.498774362
# bestIteration = 9
#
# 28:	loss: 1.4987744	best: 1.4980184 (25)	total: 33.2s	remaining: 8.02s
# 0:	learn: 1.5432303	test: 1.5450951	best: 1.5450951 (0)	total: 128ms	remaining: 1.15s
# 1:	learn: 1.5194719	test: 1.5218446	best: 1.5218446 (1)	total: 280ms	remaining: 1.12s
# 2:	learn: 1.5090376	test: 1.5122527	best: 1.5122527 (2)	total: 433ms	remaining: 1.01s
# 3:	learn: 1.5047672	test: 1.5081209	best: 1.5081209 (3)	total: 569ms	remaining: 853ms
# 4:	learn: 1.5018758	test: 1.5055122	best: 1.5055122 (4)	total: 698ms	remaining: 698ms
# 5:	learn: 1.4999359	test: 1.5038247	best: 1.5038247 (5)	total: 816ms	remaining: 544ms
# 6:	learn: 1.4974931	test: 1.5014668	best: 1.5014668 (6)	total: 942ms	remaining: 404ms
# 7:	learn: 1.4959979	test: 1.5005795	best: 1.5005795 (7)	total: 1.08s	remaining: 270ms
# 8:	learn: 1.4940967	test: 1.4990952	best: 1.4990952 (8)	total: 1.21s	remaining: 134ms
# 9:	learn: 1.4925464	test: 1.4980599	best: 1.4980599 (9)	total: 1.35s	remaining: 0us
#
# bestTest = 1.498059887
# bestIteration = 9
#
# 29:	loss: 1.4980599	best: 1.4980184 (25)	total: 34.6s	remaining: 6.93s
# 0:	learn: 1.5444551	test: 1.5462335	best: 1.5462335 (0)	total: 155ms	remaining: 1.4s
# 1:	learn: 1.5204522	test: 1.5226006	best: 1.5226006 (1)	total: 287ms	remaining: 1.15s
# 2:	learn: 1.5099899	test: 1.5122359	best: 1.5122359 (2)	total: 414ms	remaining: 967ms
# 3:	learn: 1.5050212	test: 1.5078984	best: 1.5078984 (3)	total: 537ms	remaining: 805ms
# 4:	learn: 1.5025748	test: 1.5055047	best: 1.5055047 (4)	total: 670ms	remaining: 670ms
# 5:	learn: 1.4997271	test: 1.5030654	best: 1.5030654 (5)	total: 812ms	remaining: 541ms
# 6:	learn: 1.4972144	test: 1.5010248	best: 1.5010248 (6)	total: 959ms	remaining: 411ms
# 7:	learn: 1.4956947	test: 1.4999329	best: 1.4999329 (7)	total: 1.09s	remaining: 273ms
# 8:	learn: 1.4945394	test: 1.4992188	best: 1.4992188 (8)	total: 1.25s	remaining: 139ms
# 9:	learn: 1.4932219	test: 1.4984251	best: 1.4984251 (9)	total: 1.39s	remaining: 0us
#
# bestTest = 1.498425136
# bestIteration = 9
#
# 30:	loss: 1.4984251	best: 1.4980184 (25)	total: 36.1s	remaining: 5.82s
# 0:	learn: 1.5438606	test: 1.5456818	best: 1.5456818 (0)	total: 149ms	remaining: 1.34s
# 1:	learn: 1.5199968	test: 1.5223136	best: 1.5223136 (1)	total: 286ms	remaining: 1.14s
# 2:	learn: 1.5094339	test: 1.5125769	best: 1.5125769 (2)	total: 459ms	remaining: 1.07s
# 3:	learn: 1.5051169	test: 1.5083876	best: 1.5083876 (3)	total: 605ms	remaining: 907ms
# 4:	learn: 1.5019854	test: 1.5054510	best: 1.5054510 (4)	total: 742ms	remaining: 742ms
# 5:	learn: 1.5001913	test: 1.5039835	best: 1.5039835 (5)	total: 892ms	remaining: 594ms
# 6:	learn: 1.4975739	test: 1.5018510	best: 1.5018510 (6)	total: 1.04s	remaining: 445ms
# 7:	learn: 1.4958524	test: 1.5007538	best: 1.5007538 (7)	total: 1.17s	remaining: 293ms
# 8:	learn: 1.4946559	test: 1.4996337	best: 1.4996337 (8)	total: 1.31s	remaining: 145ms
# 9:	learn: 1.4932588	test: 1.4988202	best: 1.4988202 (9)	total: 1.45s	remaining: 0us
#
# bestTest = 1.498820176
# bestIteration = 9
#
# 31:	loss: 1.4988202	best: 1.4980184 (25)	total: 37.6s	remaining: 4.7s
# 0:	learn: 1.5432858	test: 1.5451502	best: 1.5451502 (0)	total: 163ms	remaining: 1.47s
# 1:	learn: 1.5195431	test: 1.5219036	best: 1.5219036 (1)	total: 322ms	remaining: 1.29s
# 2:	learn: 1.5091239	test: 1.5123227	best: 1.5123227 (2)	total: 468ms	remaining: 1.09s
# 3:	learn: 1.5048691	test: 1.5081918	best: 1.5081918 (3)	total: 622ms	remaining: 933ms
# 4:	learn: 1.5019758	test: 1.5055766	best: 1.5055766 (4)	total: 756ms	remaining: 756ms
# 5:	learn: 1.5000380	test: 1.5038874	best: 1.5038874 (5)	total: 887ms	remaining: 592ms
# 6:	learn: 1.4974049	test: 1.5013901	best: 1.5013901 (6)	total: 1.02s	remaining: 436ms
# 7:	learn: 1.4960611	test: 1.5005889	best: 1.5005889 (7)	total: 1.14s	remaining: 285ms
# 8:	learn: 1.4940222	test: 1.4989711	best: 1.4989711 (8)	total: 1.3s	remaining: 144ms
# 9:	learn: 1.4921372	test: 1.4978363	best: 1.4978363 (9)	total: 1.42s	remaining: 0us
#
# bestTest = 1.497836338
# bestIteration = 9
#
# 32:	loss: 1.4978363	best: 1.4978363 (32)	total: 39.1s	remaining: 3.55s
# 0:	learn: 1.5445093	test: 1.5462887	best: 1.5462887 (0)	total: 136ms	remaining: 1.23s
# 1:	learn: 1.5205139	test: 1.5226580	best: 1.5226580 (1)	total: 272ms	remaining: 1.09s
# 2:	learn: 1.5100457	test: 1.5122906	best: 1.5122906 (2)	total: 401ms	remaining: 936ms
# 3:	learn: 1.5050784	test: 1.5079520	best: 1.5079520 (3)	total: 534ms	remaining: 801ms
# 4:	learn: 1.5026322	test: 1.5055623	best: 1.5055623 (4)	total: 668ms	remaining: 668ms
# 5:	learn: 1.4998016	test: 1.5031213	best: 1.5031213 (5)	total: 801ms	remaining: 534ms
# 6:	learn: 1.4972900	test: 1.5010791	best: 1.5010791 (6)	total: 962ms	remaining: 412ms
# 7:	learn: 1.4957904	test: 1.4999904	best: 1.4999904 (7)	total: 1.1s	remaining: 275ms
# 8:	learn: 1.4946408	test: 1.4992718	best: 1.4992718 (8)	total: 1.24s	remaining: 137ms
# 9:	learn: 1.4933309	test: 1.4984733	best: 1.4984733 (9)	total: 1.39s	remaining: 0us
#
# bestTest = 1.498473292
# bestIteration = 9
#
# 33:	loss: 1.4984733	best: 1.4978363 (32)	total: 40.5s	remaining: 2.38s
# 0:	learn: 1.5439139	test: 1.5457361	best: 1.5457361 (0)	total: 127ms	remaining: 1.14s
# 1:	learn: 1.5200409	test: 1.5222281	best: 1.5222281 (1)	total: 254ms	remaining: 1.01s
# 2:	learn: 1.5103047	test: 1.5132157	best: 1.5132157 (2)	total: 375ms	remaining: 876ms
# 3:	learn: 1.5055585	test: 1.5091375	best: 1.5091375 (3)	total: 504ms	remaining: 755ms
# 4:	learn: 1.5020395	test: 1.5056231	best: 1.5056231 (4)	total: 656ms	remaining: 656ms
# 5:	learn: 1.5002170	test: 1.5040223	best: 1.5040223 (5)	total: 784ms	remaining: 522ms
# 6:	learn: 1.4975877	test: 1.5018822	best: 1.5018822 (6)	total: 919ms	remaining: 394ms
# 7:	learn: 1.4961110	test: 1.5009886	best: 1.5009886 (7)	total: 1.07s	remaining: 268ms
# 8:	learn: 1.4943204	test: 1.4995346	best: 1.4995346 (8)	total: 1.2s	remaining: 133ms
# 9:	learn: 1.4924797	test: 1.4978822	best: 1.4978822 (9)	total: 1.33s	remaining: 0us
#
# bestTest = 1.497882239
# bestIteration = 9
#
# 34:	loss: 1.4978822	best: 1.4978363 (32)	total: 41.9s	remaining: 1.2s
# 0:	learn: 1.5433382	test: 1.5452036	best: 1.5452036 (0)	total: 136ms	remaining: 1.23s
# 1:	learn: 1.5196095	test: 1.5219616	best: 1.5219616 (1)	total: 269ms	remaining: 1.07s
# 2:	learn: 1.5092037	test: 1.5123912	best: 1.5123912 (2)	total: 426ms	remaining: 993ms
# 3:	learn: 1.5049613	test: 1.5082625	best: 1.5082625 (3)	total: 556ms	remaining: 834ms
# 4:	learn: 1.5020648	test: 1.5056407	best: 1.5056407 (4)	total: 680ms	remaining: 680ms
# 5:	learn: 1.5001274	test: 1.5039486	best: 1.5039486 (5)	total: 822ms	remaining: 548ms
# 6:	learn: 1.4978439	test: 1.5017057	best: 1.5017057 (6)	total: 957ms	remaining: 410ms
# 7:	learn: 1.4961347	test: 1.5004501	best: 1.5004501 (7)	total: 1.08s	remaining: 270ms
# 8:	learn: 1.4950359	test: 1.4998674	best: 1.4998674 (8)	total: 1.21s	remaining: 134ms
# 9:	learn: 1.4934287	test: 1.4985630	best: 1.4985630 (9)	total: 1.34s	remaining: 0us
#
# bestTest = 1.498562971
# bestIteration = 9
#
# 35:	loss: 1.4985630	best: 1.4978363 (32)	total: 43.3s	remaining: 0us
# Estimating final quality...
# Training on fold [0/5]
# 0:	learn: 1.5446008	test: 1.5445751	best: 1.5445751 (0)	total: 146ms	remaining: 1.31s
# 1:	learn: 1.5265405	test: 1.5262671	best: 1.5262671 (1)	total: 302ms	remaining: 1.21s
# 2:	learn: 1.5142027	test: 1.5142738	best: 1.5142738 (2)	total: 457ms	remaining: 1.06s
# 3:	learn: 1.5087774	test: 1.5088880	best: 1.5088880 (3)	total: 593ms	remaining: 889ms
# 4:	learn: 1.5045907	test: 1.5050090	best: 1.5050090 (4)	total: 741ms	remaining: 741ms
# 5:	learn: 1.5016109	test: 1.5021027	best: 1.5021027 (5)	total: 912ms	remaining: 608ms
# 6:	learn: 1.5003607	test: 1.5011552	best: 1.5011552 (6)	total: 1.06s	remaining: 454ms
# 7:	learn: 1.4975187	test: 1.4988649	best: 1.4988649 (7)	total: 1.2s	remaining: 300ms
# 8:	learn: 1.4961217	test: 1.4976259	best: 1.4976259 (8)	total: 1.35s	remaining: 150ms
# 9:	learn: 1.4947394	test: 1.4968091	best: 1.4968091 (9)	total: 1.51s	remaining: 0us
#
# bestTest = 1.496809149
# bestIteration = 9
#
# Training on fold [1/5]
# 0:	learn: 1.5440687	test: 1.5441885	best: 1.5441885 (0)	total: 154ms	remaining: 1.39s
# 1:	learn: 1.5256019	test: 1.5260989	best: 1.5260989 (1)	total: 363ms	remaining: 1.45s
# 2:	learn: 1.5137035	test: 1.5140293	best: 1.5140293 (2)	total: 521ms	remaining: 1.22s
# 3:	learn: 1.5080310	test: 1.5086638	best: 1.5086638 (3)	total: 663ms	remaining: 994ms
# 4:	learn: 1.5048041	test: 1.5059474	best: 1.5059474 (4)	total: 816ms	remaining: 816ms
# 5:	learn: 1.5025287	test: 1.5039798	best: 1.5039798 (5)	total: 951ms	remaining: 634ms
# 6:	learn: 1.4995997	test: 1.5012542	best: 1.5012542 (6)	total: 1.07s	remaining: 461ms
# 7:	learn: 1.4975015	test: 1.4994588	best: 1.4994588 (7)	total: 1.2s	remaining: 301ms
# 8:	learn: 1.4961265	test: 1.4986061	best: 1.4986061 (8)	total: 1.35s	remaining: 150ms
# 9:	learn: 1.4940773	test: 1.4968224	best: 1.4968224 (9)	total: 1.5s	remaining: 0us
#
# bestTest = 1.496822377
# bestIteration = 9
#
# Training on fold [2/5]
# 0:	learn: 1.5424650	test: 1.5423773	best: 1.5423773 (0)	total: 132ms	remaining: 1.19s
# 1:	learn: 1.5232868	test: 1.5234297	best: 1.5234297 (1)	total: 255ms	remaining: 1.02s
# 2:	learn: 1.5105083	test: 1.5113508	best: 1.5113508 (2)	total: 397ms	remaining: 927ms
# 3:	learn: 1.5067040	test: 1.5080027	best: 1.5080027 (3)	total: 526ms	remaining: 790ms
# 4:	learn: 1.5041555	test: 1.5055782	best: 1.5055782 (4)	total: 666ms	remaining: 666ms
# 5:	learn: 1.5018593	test: 1.5035870	best: 1.5035870 (5)	total: 812ms	remaining: 542ms
# 6:	learn: 1.4999781	test: 1.5019906	best: 1.5019906 (6)	total: 935ms	remaining: 401ms
# 7:	learn: 1.4981031	test: 1.5003675	best: 1.5003675 (7)	total: 1.05s	remaining: 263ms
# 8:	learn: 1.4969143	test: 1.4995890	best: 1.4995890 (8)	total: 1.18s	remaining: 131ms
# 9:	learn: 1.4950954	test: 1.4981924	best: 1.4981924 (9)	total: 1.32s	remaining: 0us
#
# bestTest = 1.498192379
# bestIteration = 9
#
# Training on fold [3/5]
# 0:	learn: 1.5450337	test: 1.5444655	best: 1.5444655 (0)	total: 119ms	remaining: 1.07s
# 1:	learn: 1.5269616	test: 1.5263881	best: 1.5263881 (1)	total: 251ms	remaining: 1s
# 2:	learn: 1.5140233	test: 1.5137076	best: 1.5137076 (2)	total: 392ms	remaining: 914ms
# 3:	learn: 1.5087470	test: 1.5085782	best: 1.5085782 (3)	total: 509ms	remaining: 764ms
# 4:	learn: 1.5056057	test: 1.5055034	best: 1.5055034 (4)	total: 633ms	remaining: 633ms
# 5:	learn: 1.5030154	test: 1.5028914	best: 1.5028914 (5)	total: 771ms	remaining: 514ms
# 6:	learn: 1.4999169	test: 1.4995339	best: 1.4995339 (6)	total: 950ms	remaining: 407ms
# 7:	learn: 1.4978417	test: 1.4978408	best: 1.4978408 (7)	total: 1.08s	remaining: 271ms
# 8:	learn: 1.4964496	test: 1.4967084	best: 1.4967084 (8)	total: 1.24s	remaining: 138ms
# 9:	learn: 1.4953548	test: 1.4958129	best: 1.4958129 (9)	total: 1.38s	remaining: 0us
#
# bestTest = 1.495812943
# bestIteration = 9
#
# Training on fold [4/5]
# 0:	learn: 1.5439982	test: 1.5467745	best: 1.5467745 (0)	total: 115ms	remaining: 1.04s
# 1:	learn: 1.5256367	test: 1.5293278	best: 1.5293278 (1)	total: 250ms	remaining: 999ms
# 2:	learn: 1.5137130	test: 1.5181587	best: 1.5181587 (2)	total: 387ms	remaining: 902ms
# 3:	learn: 1.5097410	test: 1.5148014	best: 1.5148014 (3)	total: 512ms	remaining: 767ms
# 4:	learn: 1.5045432	test: 1.5097573	best: 1.5097573 (4)	total: 645ms	remaining: 645ms
# 5:	learn: 1.5011450	test: 1.5061865	best: 1.5061865 (5)	total: 771ms	remaining: 514ms
# 6:	learn: 1.4986328	test: 1.5041385	best: 1.5041385 (6)	total: 908ms	remaining: 389ms
# 7:	learn: 1.4969754	test: 1.5029601	best: 1.5029601 (7)	total: 1.04s	remaining: 260ms
# 8:	learn: 1.4956183	test: 1.5016653	best: 1.5016653 (8)	total: 1.17s	remaining: 130ms
# 9:	learn: 1.4944234	test: 1.5008414	best: 1.5008414 (9)	total: 1.31s	remaining: 0us
#
# bestTest = 1.500841384
# bestIteration = 9
#
# {'depth': 7, 'l2_leaf_reg': 3, 'learning_rate': 0.5800000000000001}

# %%
catboost_model.fit(train_dataset)
# Out:
# 0:	learn: 1.5409125	total: 160ms	remaining: 15.9s
# 1:	learn: 1.5224255	total: 302ms	remaining: 14.8s
# 2:	learn: 1.5103595	total: 443ms	remaining: 14.3s
# 3:	learn: 1.5056707	total: 579ms	remaining: 13.9s
# 4:	learn: 1.5033266	total: 765ms	remaining: 14.5s
# 5:	learn: 1.5006863	total: 922ms	remaining: 14.4s
# 6:	learn: 1.4987258	total: 1.09s	remaining: 14.5s
# 7:	learn: 1.4965059	total: 1.27s	remaining: 14.7s
# 8:	learn: 1.4956740	total: 1.46s	remaining: 14.8s
# 9:	learn: 1.4948075	total: 1.65s	remaining: 14.9s
# 10:	learn: 1.4934014	total: 1.84s	remaining: 14.9s
# 11:	learn: 1.4922293	total: 2.02s	remaining: 14.8s
# 12:	learn: 1.4916478	total: 2.17s	remaining: 14.5s
# 13:	learn: 1.4903732	total: 2.32s	remaining: 14.3s
# 14:	learn: 1.4896515	total: 2.49s	remaining: 14.1s
# 15:	learn: 1.4889821	total: 2.65s	remaining: 13.9s
# 16:	learn: 1.4883128	total: 2.8s	remaining: 13.7s
# 17:	learn: 1.4874646	total: 2.99s	remaining: 13.6s
# 18:	learn: 1.4870891	total: 3.16s	remaining: 13.5s
# 19:	learn: 1.4865218	total: 3.34s	remaining: 13.3s
# 20:	learn: 1.4858653	total: 3.51s	remaining: 13.2s
# 21:	learn: 1.4856241	total: 3.67s	remaining: 13s
# 22:	learn: 1.4851272	total: 3.84s	remaining: 12.8s
# 23:	learn: 1.4840585	total: 3.99s	remaining: 12.7s
# 24:	learn: 1.4834125	total: 4.16s	remaining: 12.5s
# 25:	learn: 1.4829547	total: 4.31s	remaining: 12.3s
# 26:	learn: 1.4818952	total: 4.46s	remaining: 12.1s
# 27:	learn: 1.4811679	total: 4.62s	remaining: 11.9s
# 28:	learn: 1.4803171	total: 4.79s	remaining: 11.7s
# 29:	learn: 1.4795388	total: 4.96s	remaining: 11.6s
# 30:	learn: 1.4788650	total: 5.13s	remaining: 11.4s
# 31:	learn: 1.4781194	total: 5.34s	remaining: 11.3s
# 32:	learn: 1.4775929	total: 5.54s	remaining: 11.3s
# 33:	learn: 1.4767316	total: 5.75s	remaining: 11.2s
# 34:	learn: 1.4763848	total: 5.92s	remaining: 11s
# 35:	learn: 1.4760644	total: 6.12s	remaining: 10.9s
# 36:	learn: 1.4757113	total: 6.28s	remaining: 10.7s
# 37:	learn: 1.4752246	total: 6.47s	remaining: 10.6s
# 38:	learn: 1.4746998	total: 6.64s	remaining: 10.4s
# 39:	learn: 1.4740293	total: 6.83s	remaining: 10.2s
# 40:	learn: 1.4735531	total: 7.04s	remaining: 10.1s
# 41:	learn: 1.4732115	total: 7.23s	remaining: 9.98s
# 42:	learn: 1.4729465	total: 7.41s	remaining: 9.82s
# 43:	learn: 1.4725316	total: 7.62s	remaining: 9.7s
# 44:	learn: 1.4719600	total: 7.83s	remaining: 9.56s
# 45:	learn: 1.4716941	total: 8.05s	remaining: 9.46s
# 46:	learn: 1.4713524	total: 8.26s	remaining: 9.31s
# 47:	learn: 1.4711498	total: 8.43s	remaining: 9.13s
# 48:	learn: 1.4707004	total: 8.62s	remaining: 8.97s
# 49:	learn: 1.4701017	total: 8.79s	remaining: 8.79s
# 50:	learn: 1.4698736	total: 8.97s	remaining: 8.62s
# 51:	learn: 1.4696844	total: 9.13s	remaining: 8.43s
# 52:	learn: 1.4694324	total: 9.32s	remaining: 8.27s
# 53:	learn: 1.4690324	total: 9.48s	remaining: 8.07s
# 54:	learn: 1.4686605	total: 9.64s	remaining: 7.88s
# 55:	learn: 1.4684905	total: 9.81s	remaining: 7.71s
# 56:	learn: 1.4676155	total: 9.98s	remaining: 7.53s
# 57:	learn: 1.4672656	total: 10.1s	remaining: 7.33s
# 58:	learn: 1.4669159	total: 10.3s	remaining: 7.15s
# 59:	learn: 1.4666788	total: 10.4s	remaining: 6.96s
# 60:	learn: 1.4663163	total: 10.6s	remaining: 6.77s
# 61:	learn: 1.4659687	total: 10.7s	remaining: 6.58s
# 62:	learn: 1.4655527	total: 10.9s	remaining: 6.43s
# 63:	learn: 1.4654347	total: 11.1s	remaining: 6.25s
# 64:	learn: 1.4650294	total: 11.3s	remaining: 6.08s
# 65:	learn: 1.4647234	total: 11.5s	remaining: 5.91s
# 66:	learn: 1.4644191	total: 11.6s	remaining: 5.73s
# 67:	learn: 1.4641080	total: 11.8s	remaining: 5.56s
# 68:	learn: 1.4638893	total: 12s	remaining: 5.38s
# 69:	learn: 1.4635955	total: 12.1s	remaining: 5.2s
# 70:	learn: 1.4633568	total: 12.3s	remaining: 5.02s
# 71:	learn: 1.4630934	total: 12.4s	remaining: 4.84s
# 72:	learn: 1.4626544	total: 12.6s	remaining: 4.66s
# 73:	learn: 1.4624994	total: 12.8s	remaining: 4.48s
# 74:	learn: 1.4622746	total: 12.9s	remaining: 4.31s
# 75:	learn: 1.4618401	total: 13.1s	remaining: 4.14s
# 76:	learn: 1.4616204	total: 13.3s	remaining: 3.97s
# 77:	learn: 1.4614170	total: 13.5s	remaining: 3.81s
# 78:	learn: 1.4611697	total: 13.7s	remaining: 3.64s
# 79:	learn: 1.4608531	total: 13.9s	remaining: 3.46s
# 80:	learn: 1.4603749	total: 14s	remaining: 3.29s
# 81:	learn: 1.4601972	total: 14.2s	remaining: 3.11s
# 82:	learn: 1.4598389	total: 14.3s	remaining: 2.93s
# 83:	learn: 1.4596343	total: 14.5s	remaining: 2.76s
# 84:	learn: 1.4593942	total: 14.6s	remaining: 2.58s
# 85:	learn: 1.4590352	total: 14.8s	remaining: 2.41s
# 86:	learn: 1.4588614	total: 15s	remaining: 2.24s
# 87:	learn: 1.4587413	total: 15.2s	remaining: 2.07s
# 88:	learn: 1.4585596	total: 15.3s	remaining: 1.9s
# 89:	learn: 1.4583181	total: 15.5s	remaining: 1.73s
# 90:	learn: 1.4580759	total: 15.7s	remaining: 1.55s
# 91:	learn: 1.4577717	total: 15.9s	remaining: 1.38s
# 92:	learn: 1.4573611	total: 16.1s	remaining: 1.21s
# 93:	learn: 1.4572357	total: 16.2s	remaining: 1.04s
# 94:	learn: 1.4569077	total: 16.4s	remaining: 862ms
# 95:	learn: 1.4566334	total: 16.5s	remaining: 689ms
# 96:	learn: 1.4561502	total: 16.7s	remaining: 516ms
# 97:	learn: 1.4559434	total: 16.9s	remaining: 344ms
# 98:	learn: 1.4557033	total: 17s	remaining: 172ms
# 99:	learn: 1.4553413	total: 17.2s	remaining: 0us

# %% [markdown]
# ### Обогащение тестовых данных

# %%
test_data = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_test.tsv.gz', sep='\t')
test_data.head()
# Out:
#    building_series_id  site_id  parking  build_year  expect_demolition  \
# 0              663294        0  UNKNOWN        1971              False
# 1              712125        0  UNKNOWN        1986              False
# 2                   0        0  UNKNOWN        2014              False
# 3                   0        0  UNKNOWN        2001              False
# 4             1564812        0  UNKNOWN        2019              False
#
#                                           main_image   latitude  total_area  \
# 0  //avatars.mds.yandex.net/get-realty/1900763/ad...  55.795704   36.000000
# 1  //avatars.mds.yandex.net/get-realty/1583116/ad...  55.605583   40.000000
# 2  //avatars.mds.yandex.net/get-realty/2124710/ad...  55.925560   25.000000
# 3  //avatars.mds.yandex.net/get-realty/2958378/ad...  55.432522   42.000000
# 4  //avatars.mds.yandex.net/get-realty/2732616/ad...  55.917530   73.300003
#
#    ceiling_height  rooms  ...  kitchen_area         day  public  longitude  \
# 0            2.64      1  ...           0.0  2020-01-25    True  37.602478
# 1            2.48      1  ...          10.0  2019-11-19    True  37.743679
# 2            0.00      0  ...           0.0  2020-01-11    True  37.862965
# 3            0.00      1  ...          10.0  2020-01-27    True  37.544224
# 4            2.80      3  ...          10.2  2020-03-04   False  37.411098
#
#    price  flats_count  building_type     balcony locality_name     renovation
# 0  40000           80          PANEL     UNKNOWN        Москва        UNKNOWN
# 1  25000          222          PANEL      LOGGIA        Москва  COSMETIC_DONE
# 2  19000          179        MONOLIT      LOGGIA       Королёв  COSMETIC_DONE
# 3  20000            0          PANEL      LOGGIA      Подольск  COSMETIC_DONE
# 4  68000            0        MONOLIT  TWO_LOGGIA         Химки           EURO
#
# [5 rows x 30 columns]

# %% [markdown]
# Зависимость срока экспозиции от количества объявлений в день. Возможно, имеет смысл просто взять логарифм от числа объявлений в день - и использовать его для кластеризации/классификации

# %%
train = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_train.tsv.gz', sep='\t')
train_day_count = train.groupby("day").count()["target"]
train_day_mean = train.groupby("day").mean()["target"]
train["day_count"] = train["day"].apply(lambda x:train_day_count.loc[x])
train["day_mean"] = train["day"].apply(lambda x:train_day_mean.loc[x])

# %%
x = np.array(train[train["day_count"]>max(train_day_count)-1]["day_count"]).reshape(-1, 1)
y = train[train["day_count"]>max(train_day_count)-1]["day_mean"]
day_model = LinearRegression().fit(x, y)

# %%
test_day_count = test_data.groupby("day").count()["total_area"]
test_data["day_count"] = test_data["day"].apply(lambda x:test_day_count.loc[x])
test_data["day_mean"] = day_model.predict(np.array(test_data["day_count"]).reshape(-1, 1))
test_data.loc[test_data["day_count"]<max(test_data["day_count"]),"day_mean"] = train_day_mean.mean()

# %%
test_data.head(30)
# Out:
#     building_series_id  site_id  parking  build_year  expect_demolition  \
# 0               663294        0  UNKNOWN        1971              False
# 1               712125        0  UNKNOWN        1986              False
# 2                    0        0  UNKNOWN        2014              False
# 3                    0        0  UNKNOWN        2001              False
# 4              1564812        0  UNKNOWN        2019              False
# 5              1564812        0  UNKNOWN        1961              False
# 6              1564812        0  UNKNOWN        2016              False
# 7              1564812        0  UNKNOWN        1952              False
# 8              1564812        0  UNKNOWN        1966              False
# 9               663320        0  UNKNOWN        2005              False
# 10                   0        0  UNKNOWN        1980              False
# 11             1564812        0  UNKNOWN        2007              False
# 12             1564812        0  UNKNOWN        2007              False
# 13                   0        0  UNKNOWN        1971              False
# 14             1564812        0  UNKNOWN        2003              False
# 15              663278        0  UNKNOWN        1977              False
# 16              712156        0  UNKNOWN           0              False
# 17                   0        0  UNKNOWN        2008              False
# 18                   0        0  UNKNOWN        1993              False
# 19                   0        0  UNKNOWN        1996              False
# 20                   0        0  UNKNOWN        1878              False
# 21             1564812        0  UNKNOWN        2007              False
# 22             1564812        0  UNKNOWN        2018              False
# 23             1564812        0  UNKNOWN        2000              False
# 24              712125        0  UNKNOWN        1973              False
# 25              663320        0  UNKNOWN        2018              False
# 26             1564812        0  UNKNOWN           0              False
# 27              663294        0  UNKNOWN        1968              False
# 28              663278        0  UNKNOWN        1960               True
# 29                   0        0  UNKNOWN        1966              False
#
#                                            main_image   latitude  total_area  \
# 0   //avatars.mds.yandex.net/get-realty/1900763/ad...  55.795704   36.000000
# 1   //avatars.mds.yandex.net/get-realty/1583116/ad...  55.605583   40.000000
# 2   //avatars.mds.yandex.net/get-realty/2124710/ad...  55.925560   25.000000
# 3   //avatars.mds.yandex.net/get-realty/2958378/ad...  55.432522   42.000000
# 4   //avatars.mds.yandex.net/get-realty/2732616/ad...  55.917530   73.300003
# 5   //avatars.mds.yandex.net/get-realty/1651606/ad...  55.677845   32.000000
# 6   //avatars.mds.yandex.net/get-realty/2355710/ad...  55.842464   30.000000
# 7   //avatars.mds.yandex.net/get-realty/2090636/ad...  55.779575   40.000000
# 8   //avatars.mds.yandex.net/get-realty/2353363/ad...  55.765087   48.000000
# 9   //avatars.mds.yandex.net/get-realty/2771165/ad...  55.886742   52.000000
# 10  //avatars.mds.yandex.net/get-realty/1935632/ad...  55.867043   19.000000
# 11  //avatars.mds.yandex.net/get-realty/1982757/ad...  55.905396  107.000000
# 12  //avatars.mds.yandex.net/get-realty/2001447/ad...  55.947136   40.299999
# 13  //avatars.mds.yandex.net/get-realty/1968890/ad...  55.771656   32.000000
# 14  //avatars.mds.yandex.net/get-realty/2068874/ad...  55.898857   50.000000
# 15  //avatars.mds.yandex.net/get-realty/2039052/ad...  55.881207   59.900002
# 16  //avatars.mds.yandex.net/get-realty/1894107/ad...  55.621304   68.000000
# 17  //avatars.mds.yandex.net/get-realty/2784061/ad...  55.692097   77.000000
# 18  //avatars.mds.yandex.net/get-realty/2784061/ad...  55.688492   65.000000
# 19  //avatars.mds.yandex.net/get-realty/2753842/ad...  55.148903   34.500000
# 20  //avatars.mds.yandex.net/get-realty/1977245/ad...  55.783775   87.000000
# 21  //avatars.mds.yandex.net/get-realty/2807710/ad...  55.886734   43.000000
# 22  //avatars.mds.yandex.net/get-realty/2031790/ad...  55.603874   33.000000
# 23  //avatars.mds.yandex.net/get-realty/2403545/ad...  55.714821   70.000000
# 24  //avatars.mds.yandex.net/get-realty/2006831/ad...  55.598793   51.299999
# 25  //avatars.mds.yandex.net/get-realty/1581062/ad...  55.698536   42.000000
# 26  //avatars.mds.yandex.net/get-realty/2752469/ad...  55.789394   33.000000
# 27  //avatars.mds.yandex.net/get-realty/2779015/ad...  55.842773   64.199997
# 28  //avatars.mds.yandex.net/get-realty/2071710/ad...  55.699425   60.000000
# 29  //avatars.mds.yandex.net/get-realty/1974902/ad...  55.771477   45.000000
#
#     ceiling_height  rooms  ...  public  longitude   price  flats_count  \
# 0             2.64      1  ...    True  37.602478   40000           80
# 1             2.48      1  ...    True  37.743679   25000          222
# 2             0.00      0  ...    True  37.862965   19000          179
# 3             0.00      1  ...    True  37.544224   20000            0
# 4             2.80      3  ...   False  37.411098   68000            0
# 5             0.00      1  ...    True  37.564484   40000          112
# 6             3.00      0  ...   False  37.373302   45000            0
# 7             3.20      1  ...   False  37.706863   40000          115
# 8             2.70      2  ...    True  37.657494  110000           68
# 9             2.74      2  ...    True  37.647129   40000          235
# 10            3.00      0  ...    True  37.709599   30000            0
# 11            3.10      3  ...    True  37.384811   65000           94
# 12            2.64      1  ...    True  37.488331   35000            0
# 13            0.00      1  ...    True  38.443108   14000           70
# 14            3.00      1  ...    True  37.395267   38000           96
# 15            2.64      3  ...    True  37.654171   29900          215
# 16            2.48      2  ...    True  37.493809   55000          249
# 17            0.00      3  ...   False  37.910927   40000            0
# 18            2.50      3  ...   False  37.297626   37990          166
# 19            2.60      1  ...   False  37.470821   17000            0
# 20            0.00      3  ...    True  37.632374   75000            0
# 21            0.00      1  ...    True  37.426960   30000            0
# 22            2.70      0  ...    True  38.083157   22000          372
# 23            0.00      2  ...   False  37.801422   75000          101
# 24            2.48      2  ...    True  37.659466   30000            0
# 25            2.75      1  ...    True  37.935516   27000          192
# 26            3.05      0  ...    True  37.536831   55000            0
# 27            2.64      3  ...    True  37.494194   65000           80
# 28            2.64      3  ...    True  37.756870   46000           80
# 29            0.00      2  ...    True  38.436760   16000           80
#
#     building_type      balcony  locality_name           renovation day_count  \
# 0           PANEL      UNKNOWN         Москва              UNKNOWN       352
# 1           PANEL       LOGGIA         Москва        COSMETIC_DONE       553
# 2         MONOLIT       LOGGIA        Королёв        COSMETIC_DONE       381
# 3           PANEL       LOGGIA       Подольск        COSMETIC_DONE       501
# 4         MONOLIT   TWO_LOGGIA          Химки                 EURO       464
# 5           BRICK      BALCONY         Москва        COSMETIC_DONE       553
# 6         MONOLIT      UNKNOWN         Москва  DESIGNER_RENOVATION      5259
# 7           BRICK       LOGGIA         Москва                 EURO      5259
# 8           PANEL      BALCONY         Москва                 EURO       485
# 9           PANEL      BALCONY         Москва        COSMETIC_DONE      6779
# 10          BLOCK      UNKNOWN         Москва                 EURO       575
# 11        MONOLIT       LOGGIA         Москва  DESIGNER_RENOVATION       298
# 12          BRICK       LOGGIA   Долгопрудный                 EURO       293
# 13          BRICK      BALCONY   Электросталь        COSMETIC_DONE       516
# 14          BRICK      BALCONY         Москва                 EURO       513
# 15          PANEL       LOGGIA         Москва        COSMETIC_DONE       163
# 16          PANEL       LOGGIA         Москва                 EURO       621
# 17          PANEL      UNKNOWN        Люберцы              UNKNOWN       411
# 18          PANEL   TWO_LOGGIA       Одинцово        COSMETIC_DONE       569
# 19          PANEL       LOGGIA          Чехов        COSMETIC_DONE      5259
# 20        UNKNOWN      BALCONY         Москва  DESIGNER_RENOVATION       516
# 21          PANEL       LOGGIA          Химки                 EURO       504
# 22        MONOLIT       LOGGIA      Жуковский                 EURO       451
# 23          BRICK       LOGGIA         Москва  DESIGNER_RENOVATION      5259
# 24          BLOCK      UNKNOWN         Москва        COSMETIC_DONE       353
# 25          PANEL       LOGGIA         Москва        COSMETIC_DONE       642
# 26        UNKNOWN      UNKNOWN         Москва                 EURO       558
# 27          BLOCK  TWO_BALCONY         Москва                 EURO       598
# 28          PANEL      BALCONY         Москва                 EURO       543
# 29          BRICK      BALCONY   Электросталь        COSMETIC_DONE      1626
#
#     day_mean
# 0   2.931129
# 1   2.931129
# 2   2.931129
# 3   2.931129
# 4   2.931129
# 5   2.931129
# 6   2.931129
# 7   2.931129
# 8   2.931129
# 9   1.392246
# 10  2.931129
# 11  2.931129
# 12  2.931129
# 13  2.931129
# 14  2.931129
# 15  2.931129
# 16  2.931129
# 17  2.931129
# 18  2.931129
# 19  2.931129
# 20  2.931129
# 21  2.931129
# 22  2.931129
# 23  2.931129
# 24  2.931129
# 25  2.931129
# 26  2.931129
# 27  2.931129
# 28  2.931129
# 29  2.931129
#
# [30 rows x 32 columns]

# %%
test_data = data_preproccesing(test_data)
test_data.head()
# Out:
# <ipython-input-2-5ba4da441bec>:40: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   data['week'] = data['day'].dt.week
#                       building_series_id  parking  build_year  \
# id
# 13762887891614807236              663294  UNKNOWN        1971
# 14654451946329972059              712125  UNKNOWN        1986
# 17449292585625593873                   0  UNKNOWN        2014
# 15597282206699587329                   0  UNKNOWN        2001
# 3718201047023531068              1564812  UNKNOWN        2019
#
#                       expect_demolition   latitude  total_area  \
# id
# 13762887891614807236                  0  55.795704   36.000000
# 14654451946329972059                  0  55.605583   40.000000
# 17449292585625593873                  0  55.925560   25.000000
# 15597282206699587329                  0  55.432522   42.000000
# 3718201047023531068                   0  55.917530   73.300003
#
#                       ceiling_height  rooms  floors_total  living_area  ...  \
# id                                                                      ...
# 13762887891614807236            2.64      1            12    19.000000  ...
# 14654451946329972059            2.48      1            16    20.000000  ...
# 17449292585625593873            2.70      0            16    12.000000  ...
# 15597282206699587329            2.70      1            10    20.000000  ...
# 3718201047023531068             2.80      3            16    45.799999  ...
#
#                       locality_name_derevnja Kabanovo  \
# id
# 13762887891614807236                                0
# 14654451946329972059                                0
# 17449292585625593873                                0
# 15597282206699587329                                0
# 3718201047023531068                                 0
#
#                       locality_name_derevnja Ivojlovo  \
# id
# 13762887891614807236                                0
# 14654451946329972059                                0
# 17449292585625593873                                0
# 15597282206699587329                                0
# 3718201047023531068                                 0
#
#                       locality_name_selo Vozdvizhenskoe  \
# id
# 13762887891614807236                                  0
# 14654451946329972059                                  0
# 17449292585625593873                                  0
# 15597282206699587329                                  0
# 3718201047023531068                                   0
#
#                       locality_name_derevnja Dolgoe Ledovo  \
# id
# 13762887891614807236                                     0
# 14654451946329972059                                     0
# 17449292585625593873                                     0
# 15597282206699587329                                     0
# 3718201047023531068                                      0
#
#                       locality_name_derevnja Martem'janovo  \
# id
# 13762887891614807236                                     0
# 14654451946329972059                                     0
# 17449292585625593873                                     0
# 15597282206699587329                                     0
# 3718201047023531068                                      0
#
#                       locality_name_poselok Veshki  \
# id
# 13762887891614807236                             0
# 14654451946329972059                             0
# 17449292585625593873                             0
# 15597282206699587329                             0
# 3718201047023531068                              0
#
#                       locality_name_poselok Radiotsentr  \
# id
# 13762887891614807236                                  0
# 14654451946329972059                                  0
# 17449292585625593873                                  0
# 15597282206699587329                                  0
# 3718201047023531068                                   0
#
#                       locality_name_derevnja Zhilino  \
# id
# 13762887891614807236                               0
# 14654451946329972059                               0
# 17449292585625593873                               0
# 15597282206699587329                               0
# 3718201047023531068                                0
#
#                       locality_name_poselok Shuvoe  \
# id
# 13762887891614807236                             0
# 14654451946329972059                             0
# 17449292585625593873                             0
# 15597282206699587329                             0
# 3718201047023531068                              0
#
#                      locality_name_derevnja Vorschikovo
# id
# 13762887891614807236                                  0
# 14654451946329972059                                  0
# 17449292585625593873                                  0
# 15597282206699587329                                  0
# 3718201047023531068                                   0
#
# [5 rows x 879 columns]

# %% [markdown]
# Добавление средней цены

# %%
price_data = pd.DataFrame(test_data[["locality_name", "price"]])
price_groups = {"locality_name": {
    "median": price_data.groupby(["locality_name"]).median()["price"]
}}

# %%
for group in price_groups:
    print ("Processing:", group, end=" ")
    for label in price_groups[group]:
        print (label, end=" ")
        test_data["price_" + group + "_" + label] = test_data.apply(calc_price, axis=1,
                                                                      group=group, label=label)
    print ("")
# Out:
# Processing: locality_name median

# %%
test_data = pd.DataFrame(test_data[['total_area', 'ceiling_height', 'rooms', 'living_area',
                                   'price', 'day_mean', 'price_locality_name_median']])

# %%
test_data.to_csv("exposition_test.basic.csv", index=False)

# %% [markdown]
# # Формирование предсказаний

# %%
test_data = pd.read_csv('exposition_test.basic.csv')

# %%
test_data_mm = pd.DataFrame(scaler.transform(test_data))
test_data_mm.head()
# Out:
#           0         1         2         3         4         5         6
# 0 -0.618155 -0.645106 -0.861151 -0.690542 -0.089888  0.005938 -0.168322
# 1 -0.483202 -1.427399 -0.861151 -0.635189 -0.217544  0.005938 -0.276751
# 2 -0.989277 -0.351746 -2.026671 -1.078012 -0.268606  0.005938 -0.199947
# 3 -0.415725 -0.351746 -0.861151 -0.635189 -0.260095  0.005938 -0.174608
# 4  0.640286  0.137186  1.469889  0.792913  0.148401  0.005938  0.277401

# %% [markdown]
# # -----------------------

# %%
clusters = train_data_mm.groupby("label").mean()["target"]
y = pd.DataFrame(kmeans.predict(test_data_mm))
y["pred"] = y[0].apply(lambda x:clusters.iloc[x])

# %%
y_xgboost = pd.DataFrame(xgb_model.predict(test_data_mm))
y_xgboost["pred"] = y_xgboost[0].apply(lambda x:clusters.iloc[x])

# %%
y_catboost = pd.DataFrame(catboost_model.predict(test_data_mm))
y_catboost["pred"] = y_catboost[0].apply(lambda x:clusters.iloc[x])

# %%
y = (y + y_xgboost + y_catboost) / 3

# %%
y[0] = y[0].apply(lambda n: int(n))

# %%
y.head(30)
# Out:
#      0      pred
# 0   31  2.935945
# 1   29  3.281559
# 2   18  3.346789
# 3   31  3.279982
# 4   30  2.954644
# 5   25  2.960657
# 6   29  3.791062
# 7   26  2.954730
# 8   28  3.680687
# 9   26  2.557729
# 10  28  3.447025
# 11  22  3.111407
# 12  31  3.279982
# 13  33  3.016974
# 14  25  3.730868
# 15  24  3.045503
# 16  15  2.813825
# 17  30  2.954644
# 18  16  3.485015
# 19  33  3.016974
# 20  24  3.161663
# 21  25  3.304694
# 22  17  3.265205
# 23   2  2.988267
# 24  14  3.593919
# 25   8  3.693292
# 26  30  3.020296
# 27  24  2.881782
# 28  24  3.307956
# 29  14  3.073443

# %% [markdown]
# ### Загрузка решения

# %%
submission = pd.read_csv('https://video.ittensive.com/machine-learning/hacktherealty/E/exposition_sample_submission.tsv', sep='\t')
submission['target'] = np.around(y["pred"])
#submission['target'] = 3
#submission['target'] = np.around(test_data["day_mean"])
submission["target"] = submission["target"].apply(lambda x:max(1, min(x,5))).astype(np.uint8)
submission.to_csv('submission_last.tsv', sep='\t', index=False)
